# %%
import sys
sys.path.append('../')

# %%
import time
import os

import pandas as pd
import numpy as np
from sklearn.utils import resample
from sklearn.metrics import mean_squared_error

import matplotlib.pyplot as plt

import tensorflow as tf
tf.__version__
# Out:
# '2.0.0'

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 2 Physical GPUs, 2 Logical GPUs

# %%
from tensorflow.keras.metrics import Metric
class RSquare(Metric):
    """Compute R^2 score.
     This is also called as coefficient of determination.
     It tells how close are data to the fitted regression line.
     - Highest score can be 1.0 and it indicates that the predictors
       perfectly accounts for variation in the target.
     - Score 0.0 indicates that the predictors do not
       account for variation in the target.
     - It can also be negative if the model is worse.
     Usage:
     ```python
     actuals = tf.constant([1, 4, 3], dtype=tf.float32)
     preds = tf.constant([2, 4, 4], dtype=tf.float32)
     result = tf.keras.metrics.RSquare()
     result.update_state(actuals, preds)
     print('R^2 score is: ', r1.result().numpy()) # 0.57142866
    ```
    """

    def __init__(self, name='r_square', dtype=tf.float32):
        super(RSquare, self).__init__(name=name, dtype=dtype)
        self.squared_sum = self.add_weight("squared_sum", initializer="zeros")
        self.sum = self.add_weight("sum", initializer="zeros")
        self.res = self.add_weight("residual", initializer="zeros")
        self.count = self.add_weight("count", initializer="zeros")

    def update_state(self, y_true, y_pred):
        y_true = tf.convert_to_tensor(y_true, tf.float32)
        y_pred = tf.convert_to_tensor(y_pred, tf.float32)
        self.squared_sum.assign_add(tf.reduce_sum(y_true**2))
        self.sum.assign_add(tf.reduce_sum(y_true))
        self.res.assign_add(
            tf.reduce_sum(tf.square(tf.subtract(y_true, y_pred))))
        self.count.assign_add(tf.cast(tf.shape(y_true)[0], tf.float32))

    def result(self):
        mean = self.sum / self.count
        total = self.squared_sum - 2 * self.sum * mean + self.count * mean**2
        return 1 - (self.res / total)

    def reset_states(self):
        # The state of the metric will be reset at the start of each epoch.
        self.squared_sum.assign(0.0)
        self.sum.assign(0.0)
        self.res.assign(0.0)
        self.count.assign(0.0)

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.ticker import (LinearLocator, MultipleLocator, FormatStrFormatter)
from matplotlib.dates import MONDAY
from matplotlib.dates import MonthLocator, WeekdayLocator, DateFormatter
from matplotlib import gridspec
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
# %matplotlib inline

# %%
plt.rcParams['figure.figsize'] = ((8/2.54), (6/2.54))
plt.rcParams["font.family"] = "Arial"
plt.rcParams["mathtext.default"] = "rm"
plt.rcParams.update({'font.size': 11})
MARKER_SIZE = 15
cmap_m = ["#f4a6ad", "#f6957e", "#fccfa2", "#8de7be", "#86d6f2", "#24a9e4", "#b586e0", "#d7f293"]
cmap = ["#e94d5b", "#ef4d28", "#f9a54f", "#25b575", "#1bb1e7", "#1477a2", "#a662e5", "#c2f442"]

plt.rcParams['axes.spines.top'] = False
# plt.rcParams['axes.edgecolor'] = 
plt.rcParams['axes.linewidth'] = 1
plt.rcParams['lines.linewidth'] = 1.5
plt.rcParams['xtick.major.width'] = 1
plt.rcParams['xtick.minor.width'] = 1
plt.rcParams['ytick.major.width'] = 1
plt.rcParams['ytick.minor.width'] = 1

# %%
def make_patch_spines_invisible(ax):
    ax.set_frame_on(True)
    ax.patch.set_visible(False)
    for sp in ax.spines.values():
        sp.set_visible(False)

# %% [markdown]
# ## Data preparation

# %% [markdown]
# ### Hyperparameters

# %%
BEST_PATHS       = ['./models/best_MLP.h5', 
                    './models/best_LSTM.h5',
                    './models/best_AE_LSTM.h5',
                    './models/best_BiLSTM.h5',
                    './models/best_AE_BiLSTM.h5']
TRANS_BEST_PATHS = ['./models/trans_tom_MLP.h5', 
                    './models/trans_tom_LSTM.h5',
                    './models/trans_tom_AE_LSTM.h5',
                    './models/trans_tom_BiLSTM.h5',
                    './models/trans_tom_AE_BiLSTM.h5']
RAW_BEST_PATHS   = ['./models/raw_tom_MLP.h5', 
                    './models/raw_tom_LSTM.h5',
                    './models/raw_tom_AE_LSTM.h5',
                    './models/raw_tom_BiLSTM.h5',
                    './models/raw_tom_AE_BiLSTM.h5']
LEARNING_RATE = 0.001
BATCH_SIZE = 32
N_HIDDEN = 256

# %% [markdown]
# ### data loading

# %%
l = np.load('./env_set/val_tom_dataset.npz')
train_input = l['train_input']
train_label = l['train_label']
test_input = l['test_input']
test_label = l['test_label']
MAXS = l['MAXS']
MINS = l['MINS']

TIME_STEPS = l['TIME_STEPS']
OUTPUT_SIZE = l['OUTPUT_SIZE']
NUM_FEATURES = train_input.shape[-1]

# %%
print(train_input.shape)
print(train_label.shape)
print()
print(test_input.shape)
print(test_label.shape)
# Out:
# (37951, 24, 5)
# (37951, 24, 5)
#
# (83356, 24, 5)
# (83356, 24, 5)

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((train_input, train_label))
train_dataset = train_dataset.cache().shuffle(BATCH_SIZE*100).batch(BATCH_SIZE).repeat()
test_dataset = tf.data.Dataset.from_tensor_slices((test_input, test_label))
test_dataset = test_dataset.batch(BATCH_SIZE)

# %% [markdown]
# # Transfer learning - MLP

# %%
mlp_model_copy = tf.keras.models.load_model(BEST_PATHS[0])
mlp_model_copy.trainable = False

# %%
trans_mlp_model = tf.keras.Sequential([mlp_model_copy.get_layer(index=0), 
                                       mlp_model_copy.get_layer(index=1), 
                                       mlp_model_copy.get_layer(index=2), 
                                       mlp_model_copy.get_layer(index=3), 
                                       tf.keras.layers.Dense(test_label.shape[-1], name='retrain_dense')])

# %%
trans_mlp_model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
                   loss = tf.keras.losses.MeanSquaredError())

# %%
callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        filepath=TRANS_BEST_PATHS[0],
        # Path where to save the model
        # The two parameters below mean that we will overwrite
        # the current checkpoint if and only if
        # the `val_loss` score has improved.
        save_best_only=True,
        monitor='val_loss',
        verbose=1),
    tf.keras.callbacks.EarlyStopping(
  monitor='val_loss', min_delta=0.0001,  patience=20)
]

# %%
trans_mlp_model.fit(
    train_dataset, epochs = 150,
    steps_per_epoch = 144,
    callbacks=callbacks,
    validation_data = test_dataset, validation_steps = 50)
# Out:
# Train for 144 steps, validate for 50 steps
# Epoch 1/150
# 135/144 [===========================>..] - ETA: 0s - loss: 0.1562
# Epoch 00001: val_loss improved from inf to 0.00601, saving model to ./models/trans_tom_MLP.h5
# 144/144 [==============================] - 2s 17ms/step - loss: 0.1471 - val_loss: 0.0060
# Epoch 2/150
# 141/144 [============================>.] - ETA: 0s - loss: 0.0132
# Epoch 00002: val_loss did not improve from 0.00601
# 144/144 [==============================] - 1s 8ms/step - loss: 0.0131 - val_loss: 0.0093
# Epoch 3/150
# 141/144 [============================>.] - ETA: 0s - loss: 0.0110
# Epoch 00003: val_loss did not improve from 0.00601
# 144/144 [==============================] - 1s 8ms/step - loss: 0.0110 - val_loss: 0.0100
# Epoch 4/150
# 137/144 [===========================>..] - ETA: 0s - loss: 0.0125
# Epoch 00004: val_loss improved from 0.00601 to 0.00591, saving model to ./models/trans_tom_MLP.h5
# 144/144 [==============================] - 1s 8ms/step - loss: 0.0124 - val_loss: 0.0059
# Epoch 5/150
# 141/144 [============================>.] - ETA: 0s - loss: 0.0081
# Epoch 00005: val_loss did not improve from 0.00591
# 144/144 [==============================] - 1s 8ms/step - loss: 0.0081 - val_loss: 0.0117
# Epoch 6/150
# 135/144 [===========================>..] - ETA: 0s - loss: 0.0064
# Epoch 00006: val_loss did not improve from 0.00591
# 144/144 [==============================] - 1s 8ms/step - loss: 0.0064 - val_loss: 0.0099
# Epoch 7/150
# 141/144 [============================>.] - ETA: 0s - loss: 0.0635
# Epoch 00007: val_loss did not improve from 0.00591
# 144/144 [==============================] - 1s 8ms/step - loss: 0.0683 - val_loss: 0.1194
# Epoch 8/150
# 140/144 [============================>.] - ETA: 0s - loss: 0.5658
# Epoch 00008: val_loss did not improve from 0.00591
# 144/144 [==============================] - 1s 8ms/step - loss: 0.5663 - val_loss: 0.0752
# Epoch 9/150
# 141/144 [============================>.] - ETA: 0s - loss: 0.2707
# Epoch 00009: val_loss did not improve from 0.00591
# 144/144 [==============================] - 1s 7ms/step - loss: 0.2664 - val_loss: 0.0303
# Epoch 10/150
# 141/144 [============================>.] - ETA: 0s - loss: 0.0537
# Epoch 00010: val_loss did not improve from 0.00591
# 144/144 [==============================] - 1s 7ms/step - loss: 0.0532 - val_loss: 0.0093
# Epoch 11/150
# 141/144 [============================>.] - ETA: 0s - loss: 0.0234
# Epoch 00011: val_loss did not improve from 0.00591
# 144/144 [==============================] - 1s 7ms/step - loss: 0.0235 - val_loss: 0.0107
# Epoch 12/150
# 141/144 [============================>.] - ETA: 0s - loss: 0.0157
# Epoch 00012: val_loss did not improve from 0.00591
# 144/144 [==============================] - 1s 7ms/step - loss: 0.0157 - val_loss: 0.0066
# Epoch 13/150
# 141/144 [============================>.] - ETA: 0s - loss: 0.0112
# Epoch 00013: val_loss did not improve from 0.00591
# 144/144 [==============================] - 1s 7ms/step - loss: 0.0111 - val_loss: 0.0063
# Epoch 14/150
# 141/144 [============================>.] - ETA: 0s - loss: 0.0078
# Epoch 00014: val_loss did not improve from 0.00591
# 144/144 [==============================] - 1s 7ms/step - loss: 0.0078 - val_loss: 0.0072
# Epoch 15/150
# 141/144 [============================>.] - ETA: 0s - loss: 0.0082
# Epoch 00015: val_loss did not improve from 0.00591
# 144/144 [==============================] - 1s 7ms/step - loss: 0.0083 - val_loss: 0.0062
# Epoch 16/150
# 140/144 [============================>.] - ETA: 0s - loss: 0.4400
# Epoch 00016: val_loss did not improve from 0.00591
# 144/144 [==============================] - 1s 8ms/step - loss: 0.4447 - val_loss: 0.0981
# Epoch 17/150
# 139/144 [===========================>..] - ETA: 0s - loss: 0.3939
# Epoch 00017: val_loss did not improve from 0.00591
# 144/144 [==============================] - 1s 8ms/step - loss: 0.3826 - val_loss: 0.0295
# Epoch 18/150
# 141/144 [============================>.] - ETA: 0s - loss: 0.0703
# Epoch 00018: val_loss did not improve from 0.00591
# 144/144 [==============================] - 1s 7ms/step - loss: 0.0694 - val_loss: 0.0135
# Epoch 19/150
# 141/144 [============================>.] - ETA: 0s - loss: 0.0273
# Epoch 00019: val_loss did not improve from 0.00591
# 144/144 [==============================] - 1s 7ms/step - loss: 0.0271 - val_loss: 0.0109
# Epoch 20/150
# 141/144 [============================>.] - ETA: 0s - loss: 0.0171
# Epoch 00020: val_loss did not improve from 0.00591
# 144/144 [==============================] - 1s 7ms/step - loss: 0.0172 - val_loss: 0.0076
# Epoch 21/150
# 141/144 [============================>.] - ETA: 0s - loss: 0.0137
# Epoch 00021: val_loss did not improve from 0.00591
# 144/144 [==============================] - 1s 7ms/step - loss: 0.0136 - val_loss: 0.0080

# %%
trans_mlp_model = tf.keras.models.load_model(TRANS_BEST_PATHS[0])
trans_mlp_model.trainable = True
trans_mlp_model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE/10),
                   loss = tf.keras.losses.MeanSquaredError())

# %%
trans_mlp_model.fit(
    train_dataset, epochs = 150,
    steps_per_epoch = 144,
    callbacks=callbacks,
    validation_data = test_dataset, validation_steps = 50)
# Out:
# Train for 144 steps, validate for 50 steps
# Epoch 1/150
# 137/144 [===========================>..] - ETA: 0s - loss: 0.0068
# Epoch 00001: val_loss improved from 0.00591 to 0.00437, saving model to ./models/trans_tom_MLP.h5
# 144/144 [==============================] - 2s 17ms/step - loss: 0.0070 - val_loss: 0.0044
# Epoch 2/150
# 142/144 [============================>.] - ETA: 0s - loss: 0.0087
# Epoch 00002: val_loss did not improve from 0.00437
# 144/144 [==============================] - 1s 9ms/step - loss: 0.0086 - val_loss: 0.0058
# Epoch 3/150
# 139/144 [===========================>..] - ETA: 0s - loss: 0.0096
# Epoch 00003: val_loss did not improve from 0.00437
# 144/144 [==============================] - 1s 9ms/step - loss: 0.0097 - val_loss: 0.0065
# Epoch 4/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0105
# Epoch 00004: val_loss did not improve from 0.00437
# 144/144 [==============================] - 1s 9ms/step - loss: 0.0105 - val_loss: 0.0047
# Epoch 5/150
# 141/144 [============================>.] - ETA: 0s - loss: 0.0070
# Epoch 00005: val_loss did not improve from 0.00437
# 144/144 [==============================] - 1s 10ms/step - loss: 0.0070 - val_loss: 0.0062
# Epoch 6/150
# 141/144 [============================>.] - ETA: 0s - loss: 0.0055
# Epoch 00006: val_loss did not improve from 0.00437
# 144/144 [==============================] - 1s 10ms/step - loss: 0.0055 - val_loss: 0.0064
# Epoch 7/150
# 142/144 [============================>.] - ETA: 0s - loss: 0.0340
# Epoch 00007: val_loss did not improve from 0.00437
# 144/144 [==============================] - 1s 10ms/step - loss: 0.0346 - val_loss: 0.0152
# Epoch 8/150
# 140/144 [============================>.] - ETA: 0s - loss: 0.3554
# Epoch 00008: val_loss did not improve from 0.00437
# 144/144 [==============================] - 1s 10ms/step - loss: 0.3568 - val_loss: 0.0886
# Epoch 9/150
# 140/144 [============================>.] - ETA: 0s - loss: 0.1008
# Epoch 00009: val_loss did not improve from 0.00437
# 144/144 [==============================] - 1s 10ms/step - loss: 0.0983 - val_loss: 0.0059
# Epoch 10/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0097
# Epoch 00010: val_loss did not improve from 0.00437
# 144/144 [==============================] - 1s 10ms/step - loss: 0.0096 - val_loss: 0.0064
# Epoch 11/150
# 141/144 [============================>.] - ETA: 0s - loss: 0.0085
# Epoch 00011: val_loss did not improve from 0.00437
# 144/144 [==============================] - 1s 10ms/step - loss: 0.0085 - val_loss: 0.0074
# Epoch 12/150
# 142/144 [============================>.] - ETA: 0s - loss: 0.0109
# Epoch 00012: val_loss did not improve from 0.00437
# 144/144 [==============================] - 1s 9ms/step - loss: 0.0109 - val_loss: 0.0052
# Epoch 13/150
# 137/144 [===========================>..] - ETA: 0s - loss: 0.0078
# Epoch 00013: val_loss did not improve from 0.00437
# 144/144 [==============================] - 1s 10ms/step - loss: 0.0077 - val_loss: 0.0052
# Epoch 14/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0058
# Epoch 00014: val_loss did not improve from 0.00437
# 144/144 [==============================] - 1s 10ms/step - loss: 0.0058 - val_loss: 0.0057
# Epoch 15/150
# 141/144 [============================>.] - ETA: 0s - loss: 0.0064
# Epoch 00015: val_loss did not improve from 0.00437
# 144/144 [==============================] - 1s 10ms/step - loss: 0.0064 - val_loss: 0.0056
# Epoch 16/150
# 141/144 [============================>.] - ETA: 0s - loss: 0.1551
# Epoch 00016: val_loss did not improve from 0.00437
# 144/144 [==============================] - 1s 10ms/step - loss: 0.1573 - val_loss: 0.0305
# Epoch 17/150
# 140/144 [============================>.] - ETA: 0s - loss: 0.1220
# Epoch 00017: val_loss did not improve from 0.00437
# 144/144 [==============================] - 1s 9ms/step - loss: 0.1188 - val_loss: 0.0055
# Epoch 18/150
# 141/144 [============================>.] - ETA: 0s - loss: 0.0078
# Epoch 00018: val_loss did not improve from 0.00437
# 144/144 [==============================] - 1s 9ms/step - loss: 0.0078 - val_loss: 0.0063
# Epoch 19/150
# 142/144 [============================>.] - ETA: 0s - loss: 0.0074
# Epoch 00019: val_loss did not improve from 0.00437
# 144/144 [==============================] - 1s 10ms/step - loss: 0.0074 - val_loss: 0.0053
# Epoch 20/150
# 141/144 [============================>.] - ETA: 0s - loss: 0.0102
# Epoch 00020: val_loss did not improve from 0.00437
# 144/144 [==============================] - 1s 10ms/step - loss: 0.0102 - val_loss: 0.0052
# Epoch 21/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0088
# Epoch 00021: val_loss did not improve from 0.00437
# 144/144 [==============================] - 1s 9ms/step - loss: 0.0088 - val_loss: 0.0049

# %%
raw_mlp_model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(N_HIDDEN, input_shape=[TIME_STEPS, NUM_FEATURES]),
    tf.keras.layers.LayerNormalization(),
    tf.keras.layers.Dense(N_HIDDEN),
    tf.keras.layers.LayerNormalization(),
    tf.keras.layers.Dense(test_label.shape[-1])
])

# %%
raw_mlp_model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
                   loss = tf.keras.losses.MeanSquaredError())

# %%
callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        filepath=RAW_BEST_PATHS[0],
        # Path where to save the model
        # The two parameters below mean that we will overwrite
        # the current checkpoint if and only if
        # the `val_loss` score has improved.
        save_best_only=True,
        monitor='val_loss',
        verbose=1),
    tf.keras.callbacks.EarlyStopping(
  monitor='val_loss', min_delta=0.0001,  patience=20)
]

# %%
raw_mlp_model.fit(
    train_dataset, epochs = 150,
    steps_per_epoch = 144,
    callbacks=callbacks,
    validation_data = test_dataset, validation_steps = 50)
# Out:
# Train for 144 steps, validate for 50 steps
# Epoch 1/150
# 142/144 [============================>.] - ETA: 0s - loss: 0.0694
# Epoch 00001: val_loss improved from inf to 0.00550, saving model to ./models/raw_tom_MLP.h5
# 144/144 [==============================] - 2s 17ms/step - loss: 0.0686 - val_loss: 0.0055
# Epoch 2/150
# 142/144 [============================>.] - ETA: 0s - loss: 0.0093
# Epoch 00002: val_loss did not improve from 0.00550
# 144/144 [==============================] - 1s 10ms/step - loss: 0.0093 - val_loss: 0.0065
# Epoch 3/150
# 142/144 [============================>.] - ETA: 0s - loss: 0.0099
# Epoch 00003: val_loss did not improve from 0.00550
# 144/144 [==============================] - 1s 10ms/step - loss: 0.0099 - val_loss: 0.0100
# Epoch 4/150
# 141/144 [============================>.] - ETA: 0s - loss: 0.0116
# Epoch 00004: val_loss did not improve from 0.00550
# 144/144 [==============================] - 1s 10ms/step - loss: 0.0116 - val_loss: 0.0060
# Epoch 5/150
# 142/144 [============================>.] - ETA: 0s - loss: 0.0084
# Epoch 00005: val_loss did not improve from 0.00550
# 144/144 [==============================] - 1s 10ms/step - loss: 0.0083 - val_loss: 0.0070
# Epoch 6/150
# 136/144 [===========================>..] - ETA: 0s - loss: 0.0061
# Epoch 00006: val_loss did not improve from 0.00550
# 144/144 [==============================] - 1s 9ms/step - loss: 0.0061 - val_loss: 0.0078
# Epoch 7/150
# 142/144 [============================>.] - ETA: 0s - loss: 0.0270
# Epoch 00007: val_loss did not improve from 0.00550
# 144/144 [==============================] - 1s 9ms/step - loss: 0.0274 - val_loss: 0.0577
# Epoch 8/150
# 138/144 [===========================>..] - ETA: 0s - loss: 0.2968
# Epoch 00008: val_loss did not improve from 0.00550
# 144/144 [==============================] - 1s 9ms/step - loss: 0.2964 - val_loss: 0.0252
# Epoch 9/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0660
# Epoch 00009: val_loss improved from 0.00550 to 0.00515, saving model to ./models/raw_tom_MLP.h5
# 144/144 [==============================] - 1s 10ms/step - loss: 0.0656 - val_loss: 0.0051
# Epoch 10/150
# 138/144 [===========================>..] - ETA: 0s - loss: 0.0077
# Epoch 00010: val_loss did not improve from 0.00515
# 144/144 [==============================] - 1s 9ms/step - loss: 0.0077 - val_loss: 0.0057
# Epoch 11/150
# 141/144 [============================>.] - ETA: 0s - loss: 0.0082
# Epoch 00011: val_loss did not improve from 0.00515
# 144/144 [==============================] - 1s 10ms/step - loss: 0.0082 - val_loss: 0.0057
# Epoch 12/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0107
# Epoch 00012: val_loss improved from 0.00515 to 0.00503, saving model to ./models/raw_tom_MLP.h5
# 144/144 [==============================] - 1s 10ms/step - loss: 0.0107 - val_loss: 0.0050
# Epoch 13/150
# 142/144 [============================>.] - ETA: 0s - loss: 0.0079
# Epoch 00013: val_loss improved from 0.00503 to 0.00479, saving model to ./models/raw_tom_MLP.h5
# 144/144 [==============================] - 1s 10ms/step - loss: 0.0079 - val_loss: 0.0048
# Epoch 14/150
# 141/144 [============================>.] - ETA: 0s - loss: 0.0060
# Epoch 00014: val_loss did not improve from 0.00479
# 144/144 [==============================] - 1s 9ms/step - loss: 0.0060 - val_loss: 0.0051
# Epoch 15/150
# 142/144 [============================>.] - ETA: 0s - loss: 0.0061
# Epoch 00015: val_loss did not improve from 0.00479
# 144/144 [==============================] - 1s 10ms/step - loss: 0.0062 - val_loss: 0.0052
# Epoch 16/150
# 137/144 [===========================>..] - ETA: 0s - loss: 0.1178
# Epoch 00016: val_loss did not improve from 0.00479
# 144/144 [==============================] - 1s 9ms/step - loss: 0.1200 - val_loss: 0.0120
# Epoch 17/150
# 139/144 [===========================>..] - ETA: 0s - loss: 0.1083
# Epoch 00017: val_loss did not improve from 0.00479
# 144/144 [==============================] - 1s 9ms/step - loss: 0.1048 - val_loss: 0.0053
# Epoch 18/150
# 137/144 [===========================>..] - ETA: 0s - loss: 0.0071
# Epoch 00018: val_loss did not improve from 0.00479
# 144/144 [==============================] - 1s 8ms/step - loss: 0.0071 - val_loss: 0.0059
# Epoch 19/150
# 141/144 [============================>.] - ETA: 0s - loss: 0.0074
# Epoch 00019: val_loss did not improve from 0.00479
# 144/144 [==============================] - 1s 9ms/step - loss: 0.0074 - val_loss: 0.0060
# Epoch 20/150
# 142/144 [============================>.] - ETA: 0s - loss: 0.0103
# Epoch 00020: val_loss did not improve from 0.00479
# 144/144 [==============================] - 1s 9ms/step - loss: 0.0103 - val_loss: 0.0051
# Epoch 21/150
# 141/144 [============================>.] - ETA: 0s - loss: 0.0088
# Epoch 00021: val_loss improved from 0.00479 to 0.00477, saving model to ./models/raw_tom_MLP.h5
# 144/144 [==============================] - 1s 10ms/step - loss: 0.0087 - val_loss: 0.0048
# Epoch 22/150
# 142/144 [============================>.] - ETA: 0s - loss: 0.0061
# Epoch 00022: val_loss did not improve from 0.00477
# 144/144 [==============================] - 1s 9ms/step - loss: 0.0061 - val_loss: 0.0052
# Epoch 23/150
# 142/144 [============================>.] - ETA: 0s - loss: 0.0055
# Epoch 00023: val_loss did not improve from 0.00477
# 144/144 [==============================] - 1s 10ms/step - loss: 0.0055 - val_loss: 0.0054
# Epoch 24/150
# 141/144 [============================>.] - ETA: 0s - loss: 0.0669
# Epoch 00024: val_loss did not improve from 0.00477
# 144/144 [==============================] - 1s 10ms/step - loss: 0.0693 - val_loss: 0.0108
# Epoch 25/150
# 138/144 [===========================>..] - ETA: 0s - loss: 0.1500
# Epoch 00025: val_loss did not improve from 0.00477
# 144/144 [==============================] - 1s 9ms/step - loss: 0.1442 - val_loss: 0.0061
# Epoch 26/150
# 140/144 [============================>.] - ETA: 0s - loss: 0.0067
# Epoch 00026: val_loss did not improve from 0.00477
# 144/144 [==============================] - 1s 9ms/step - loss: 0.0067 - val_loss: 0.0062
# Epoch 27/150
# 141/144 [============================>.] - ETA: 0s - loss: 0.0073
# Epoch 00027: val_loss did not improve from 0.00477
# 144/144 [==============================] - 1s 9ms/step - loss: 0.0072 - val_loss: 0.0052
# Epoch 28/150
# 140/144 [============================>.] - ETA: 0s - loss: 0.0096
# Epoch 00028: val_loss did not improve from 0.00477
# 144/144 [==============================] - 1s 9ms/step - loss: 0.0096 - val_loss: 0.0050
# Epoch 29/150
# 136/144 [===========================>..] - ETA: 0s - loss: 0.0091
# Epoch 00029: val_loss did not improve from 0.00477
# 144/144 [==============================] - 1s 9ms/step - loss: 0.0091 - val_loss: 0.0048
# Epoch 30/150
# 141/144 [============================>.] - ETA: 0s - loss: 0.0067
# Epoch 00030: val_loss did not improve from 0.00477
# 144/144 [==============================] - 1s 10ms/step - loss: 0.0066 - val_loss: 0.0051
# Epoch 31/150
# 141/144 [============================>.] - ETA: 0s - loss: 0.0055
# Epoch 00031: val_loss did not improve from 0.00477
# 144/144 [==============================] - 1s 10ms/step - loss: 0.0055 - val_loss: 0.0051
# Epoch 32/150
# 142/144 [============================>.] - ETA: 0s - loss: 0.0270
# Epoch 00032: val_loss did not improve from 0.00477
# 144/144 [==============================] - 1s 9ms/step - loss: 0.0282 - val_loss: 0.0096
# Epoch 33/150
# 142/144 [============================>.] - ETA: 0s - loss: 0.1784
# Epoch 00033: val_loss did not improve from 0.00477
# 144/144 [==============================] - 1s 9ms/step - loss: 0.1761 - val_loss: 0.0068

# %% [markdown]
# ### Model evaluation

# %%
mlp_model = tf.keras.models.load_model(BEST_PATHS[0])
trans_mlp_model = tf.keras.models.load_model(TRANS_BEST_PATHS[0])
raw_mlp_model = tf.keras.models.load_model(RAW_BEST_PATHS[0])

# %%
mlp_pred = mlp_model.predict(test_dataset)
trans_mlp_pred = trans_mlp_model.predict(test_dataset)
raw_mlp_pred = raw_mlp_model.predict(test_dataset)

# %%
fig = plt.figure(figsize=((6/2.54)*4, (6/2.54)*4))

plt.scatter(tf.cast(tf.reshape(((MAXS-MINS)*test_label + MINS)[:, :, 0], (-1, 1)), tf.float32),
            tf.cast(tf.reshape(((MAXS-MINS)*mlp_pred + MINS)[:, :, 0], (-1, 1)), tf.float32),
            c=cmap[3], s=2, alpha=0.3
           )
plt.scatter(tf.cast(tf.reshape(((MAXS-MINS)*test_label + MINS)[:, :, 0], (-1, 1)), tf.float32),
            tf.cast(tf.reshape(((MAXS-MINS)*raw_mlp_pred + MINS)[:, :, 0], (-1, 1)), tf.float32),
            c=cmap[4], s=2, alpha=0.3
           )
plt.scatter(tf.cast(tf.reshape(((MAXS-MINS)*test_label + MINS)[:, :, 0], (-1, 1)), tf.float32),
            tf.cast(tf.reshape(((MAXS-MINS)*trans_mlp_pred + MINS)[:, :, 0], (-1, 1)), tf.float32),
            c=cmap[0], s=2, alpha=0.3
           )
plt.axis([0,50,0,50])
# Out:
# [0, 50, 0, 50]

# %%
x_t = np.arange(0, test_label.shape[1])
for _ in range (6):

        NUMBERS = np.arange(1, mlp_pred.shape[0])
        np.random.shuffle(NUMBERS)
        NUMBERS = NUMBERS[:6]
        position = 331
        fig = plt.figure(figsize=((8.5/2.54)*4, (6/2.54)*4))
        
        i=0
        for NUMBER in NUMBERS:
            ax = plt.subplot(position)
            measured1 = plt.plot(x_t, test_label[NUMBER, :, i], c='k', alpha=1) #measured
            expect1 = plt.plot(x_t, mlp_pred[NUMBER, :, i], c=cmap[3], alpha=0.8) #estimated
            expect1 = plt.plot(x_t, raw_mlp_pred[NUMBER, :, i], c=cmap[4], alpha=0.8) #estimated
            expect1 = plt.plot(x_t, trans_mlp_pred[NUMBER, :, i], c=cmap[0], alpha=0.8) #estimated
            ax.axis('off')

            position += 1
        plt.show()
        _ += 1

# %% [markdown]
# # Transfer learning - LSTM

# %%
lstm_model_copy = tf.keras.models.load_model(BEST_PATHS[1])
lstm_model_copy.trainable = False

# %%
trans_lstm_model = tf.keras.Sequential([lstm_model_copy.get_layer(index=0), 
                                       lstm_model_copy.get_layer(index=1),
                                       tf.keras.layers.Dense(test_label.shape[-1], name='retrain_dense')])

# %%
trans_lstm_model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
                   loss = tf.keras.losses.MeanSquaredError())

# %%
callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        filepath=TRANS_BEST_PATHS[1],
        save_best_only=True,
        monitor='val_loss',
        verbose=1),
    tf.keras.callbacks.EarlyStopping(
  monitor='val_loss', min_delta=0.0001,  patience=20)
]

# %%
trans_lstm_model.fit(
    train_dataset, epochs = 150,
    steps_per_epoch = 144,
    callbacks=callbacks,
    validation_data = test_dataset, validation_steps = 50)
# Out:
# Train for 144 steps, validate for 50 steps
# Epoch 1/150
# 142/144 [============================>.] - ETA: 0s - loss: 0.2643
# Epoch 00001: val_loss improved from inf to 0.00814, saving model to ./models/trans_tom_LSTM.h5
# 144/144 [==============================] - 7s 46ms/step - loss: 0.2608 - val_loss: 0.0081
# Epoch 2/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0121
# Epoch 00002: val_loss improved from 0.00814 to 0.00770, saving model to ./models/trans_tom_LSTM.h5
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0121 - val_loss: 0.0077
# Epoch 3/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0110
# Epoch 00003: val_loss did not improve from 0.00770
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0110 - val_loss: 0.0078
# Epoch 4/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0108
# Epoch 00004: val_loss improved from 0.00770 to 0.00536, saving model to ./models/trans_tom_LSTM.h5
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0108 - val_loss: 0.0054
# Epoch 5/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0072
# Epoch 00005: val_loss did not improve from 0.00536
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0072 - val_loss: 0.0060
# Epoch 6/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0058
# Epoch 00006: val_loss did not improve from 0.00536
# 144/144 [==============================] - 5s 37ms/step - loss: 0.0058 - val_loss: 0.0059
# Epoch 7/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0149
# Epoch 00007: val_loss did not improve from 0.00536
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0149 - val_loss: 0.0082
# Epoch 8/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.2175
# Epoch 00008: val_loss did not improve from 0.00536
# 144/144 [==============================] - 5s 36ms/step - loss: 0.2180 - val_loss: 0.0169
# Epoch 9/150
# 142/144 [============================>.] - ETA: 0s - loss: 0.0602
# Epoch 00009: val_loss improved from 0.00536 to 0.00518, saving model to ./models/trans_tom_LSTM.h5
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0594 - val_loss: 0.0052
# Epoch 10/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0067
# Epoch 00010: val_loss improved from 0.00518 to 0.00486, saving model to ./models/trans_tom_LSTM.h5
# 144/144 [==============================] - 5s 37ms/step - loss: 0.0067 - val_loss: 0.0049
# Epoch 11/150
# 142/144 [============================>.] - ETA: 0s - loss: 0.0077
# Epoch 00011: val_loss improved from 0.00486 to 0.00466, saving model to ./models/trans_tom_LSTM.h5
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0078 - val_loss: 0.0047
# Epoch 12/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0095
# Epoch 00012: val_loss improved from 0.00466 to 0.00446, saving model to ./models/trans_tom_LSTM.h5
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0095 - val_loss: 0.0045
# Epoch 13/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0067
# Epoch 00013: val_loss did not improve from 0.00446
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0067 - val_loss: 0.0045
# Epoch 14/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0053
# Epoch 00014: val_loss did not improve from 0.00446
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0053 - val_loss: 0.0049
# Epoch 15/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0056
# Epoch 00015: val_loss did not improve from 0.00446
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0056 - val_loss: 0.0049
# Epoch 16/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.1208
# Epoch 00016: val_loss did not improve from 0.00446
# 144/144 [==============================] - 5s 36ms/step - loss: 0.1208 - val_loss: 0.0082
# Epoch 17/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.1006
# Epoch 00017: val_loss did not improve from 0.00446
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0999 - val_loss: 0.0046
# Epoch 18/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0058
# Epoch 00018: val_loss did not improve from 0.00446
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0058 - val_loss: 0.0046
# Epoch 19/150
# 142/144 [============================>.] - ETA: 0s - loss: 0.0065
# Epoch 00019: val_loss improved from 0.00446 to 0.00436, saving model to ./models/trans_tom_LSTM.h5
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0066 - val_loss: 0.0044
# Epoch 20/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0091
# Epoch 00020: val_loss improved from 0.00436 to 0.00434, saving model to ./models/trans_tom_LSTM.h5
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0091 - val_loss: 0.0043
# Epoch 21/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0073
# Epoch 00021: val_loss improved from 0.00434 to 0.00428, saving model to ./models/trans_tom_LSTM.h5
# 144/144 [==============================] - 5s 37ms/step - loss: 0.0073 - val_loss: 0.0043
# Epoch 22/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0055
# Epoch 00022: val_loss did not improve from 0.00428
# 144/144 [==============================] - 5s 35ms/step - loss: 0.0054 - val_loss: 0.0048
# Epoch 23/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0048
# Epoch 00023: val_loss did not improve from 0.00428
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0048 - val_loss: 0.0046
# Epoch 24/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0678
# Epoch 00024: val_loss did not improve from 0.00428
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0687 - val_loss: 0.0061
# Epoch 25/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.1432
# Epoch 00025: val_loss did not improve from 0.00428
# 144/144 [==============================] - 5s 35ms/step - loss: 0.1422 - val_loss: 0.0045
# Epoch 26/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0058
# Epoch 00026: val_loss did not improve from 0.00428
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0058 - val_loss: 0.0046
# Epoch 27/150
# 142/144 [============================>.] - ETA: 0s - loss: 0.0062
# Epoch 00027: val_loss did not improve from 0.00428
# 144/144 [==============================] - 5s 35ms/step - loss: 0.0062 - val_loss: 0.0045
# Epoch 28/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0085
# Epoch 00028: val_loss did not improve from 0.00428
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0085 - val_loss: 0.0046
# Epoch 29/150
# 142/144 [============================>.] - ETA: 0s - loss: 0.0080
# Epoch 00029: val_loss did not improve from 0.00428
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0080 - val_loss: 0.0043
# Epoch 30/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0055
# Epoch 00030: val_loss did not improve from 0.00428
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0055 - val_loss: 0.0045
# Epoch 31/150
# 142/144 [============================>.] - ETA: 0s - loss: 0.0048
# Epoch 00031: val_loss did not improve from 0.00428
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0048 - val_loss: 0.0046
# Epoch 32/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0251
# Epoch 00032: val_loss did not improve from 0.00428
# 144/144 [==============================] - 5s 35ms/step - loss: 0.0264 - val_loss: 0.0062
# Epoch 33/150
# 142/144 [============================>.] - ETA: 0s - loss: 0.1795
# Epoch 00033: val_loss did not improve from 0.00428
# 144/144 [==============================] - 5s 36ms/step - loss: 0.1771 - val_loss: 0.0049
# Epoch 34/150
# 142/144 [============================>.] - ETA: 0s - loss: 0.0057
# Epoch 00034: val_loss did not improve from 0.00428
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0057 - val_loss: 0.0046
# Epoch 35/150
# 142/144 [============================>.] - ETA: 0s - loss: 0.0059
# Epoch 00035: val_loss did not improve from 0.00428
# 144/144 [==============================] - 5s 35ms/step - loss: 0.0059 - val_loss: 0.0044
# Epoch 36/150
# 142/144 [============================>.] - ETA: 0s - loss: 0.0081
# Epoch 00036: val_loss did not improve from 0.00428
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0081 - val_loss: 0.0046
# Epoch 37/150
# 142/144 [============================>.] - ETA: 0s - loss: 0.0086
# Epoch 00037: val_loss improved from 0.00428 to 0.00422, saving model to ./models/trans_tom_LSTM.h5
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0086 - val_loss: 0.0042
# Epoch 38/150
# 142/144 [============================>.] - ETA: 0s - loss: 0.0059
# Epoch 00038: val_loss did not improve from 0.00422
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0059 - val_loss: 0.0047
# Epoch 39/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0050
# Epoch 00039: val_loss did not improve from 0.00422
# 144/144 [==============================] - 5s 35ms/step - loss: 0.0050 - val_loss: 0.0046
# Epoch 40/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0076
# Epoch 00040: val_loss did not improve from 0.00422
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0078 - val_loss: 0.0047
# Epoch 41/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.1580
# Epoch 00041: val_loss did not improve from 0.00422
# 144/144 [==============================] - 5s 36ms/step - loss: 0.1585 - val_loss: 0.0066
# Epoch 42/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0390
# Epoch 00042: val_loss did not improve from 0.00422
# 144/144 [==============================] - 5s 35ms/step - loss: 0.0388 - val_loss: 0.0047
# Epoch 43/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0057
# Epoch 00043: val_loss did not improve from 0.00422
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0057 - val_loss: 0.0046
# Epoch 44/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0073
# Epoch 00044: val_loss did not improve from 0.00422
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0073 - val_loss: 0.0043
# Epoch 45/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0091
# Epoch 00045: val_loss improved from 0.00422 to 0.00421, saving model to ./models/trans_tom_LSTM.h5
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0091 - val_loss: 0.0042
# Epoch 46/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0063
# Epoch 00046: val_loss did not improve from 0.00421
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0063 - val_loss: 0.0044
# Epoch 47/150
# 142/144 [============================>.] - ETA: 0s - loss: 0.0051
# Epoch 00047: val_loss did not improve from 0.00421
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0051 - val_loss: 0.0044
# Epoch 48/150
# 142/144 [============================>.] - ETA: 0s - loss: 0.0052
# Epoch 00048: val_loss did not improve from 0.00421
# 144/144 [==============================] - 5s 35ms/step - loss: 0.0053 - val_loss: 0.0052
# Epoch 49/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.1195
# Epoch 00049: val_loss did not improve from 0.00421
# 144/144 [==============================] - 5s 35ms/step - loss: 0.1195 - val_loss: 0.0053
# Epoch 50/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0776
# Epoch 00050: val_loss did not improve from 0.00421
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0771 - val_loss: 0.0043
# Epoch 51/150
# 142/144 [============================>.] - ETA: 0s - loss: 0.0056
# Epoch 00051: val_loss did not improve from 0.00421
# 144/144 [==============================] - 5s 35ms/step - loss: 0.0056 - val_loss: 0.0045
# Epoch 52/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0065
# Epoch 00052: val_loss did not improve from 0.00421
# 144/144 [==============================] - 5s 35ms/step - loss: 0.0065 - val_loss: 0.0044
# Epoch 53/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0092
# Epoch 00053: val_loss did not improve from 0.00421
# 144/144 [==============================] - 5s 35ms/step - loss: 0.0092 - val_loss: 0.0042
# Epoch 54/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 00054: val_loss did not improve from 0.00421
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0071 - val_loss: 0.0043
# Epoch 55/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0053
# Epoch 00055: val_loss did not improve from 0.00421
# 144/144 [==============================] - 5s 37ms/step - loss: 0.0052 - val_loss: 0.0046
# Epoch 56/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0047
# Epoch 00056: val_loss did not improve from 0.00421
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0047 - val_loss: 0.0047
# Epoch 57/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0687
# Epoch 00057: val_loss did not improve from 0.00421
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0699 - val_loss: 0.0050

# %%
trans_lstm_model = tf.keras.models.load_model(TRANS_BEST_PATHS[1])
trans_lstm_model.trainable = True
trans_lstm_model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE/10),
                   loss = tf.keras.losses.MeanSquaredError())

# %%
trans_lstm_model.fit(
    train_dataset, epochs = 150,
    steps_per_epoch = 144,
    callbacks=callbacks,
    validation_data = test_dataset, validation_steps = 50)
# Out:
# Train for 144 steps, validate for 50 steps
# Epoch 1/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0057
# Epoch 00001: val_loss did not improve from 0.00421
# 144/144 [==============================] - 7s 46ms/step - loss: 0.0057 - val_loss: 0.0045
# Epoch 2/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0055
# Epoch 00002: val_loss did not improve from 0.00421
# 144/144 [==============================] - 5s 37ms/step - loss: 0.0056 - val_loss: 0.0044
# Epoch 3/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0077
# Epoch 00003: val_loss did not improve from 0.00421
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0077 - val_loss: 0.0044
# Epoch 4/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0085
# Epoch 00004: val_loss improved from 0.00421 to 0.00411, saving model to ./models/trans_tom_LSTM.h5
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0085 - val_loss: 0.0041
# Epoch 5/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0057
# Epoch 00005: val_loss did not improve from 0.00411
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0057 - val_loss: 0.0041
# Epoch 6/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0047
# Epoch 00006: val_loss did not improve from 0.00411
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0047 - val_loss: 0.0048
# Epoch 7/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0067
# Epoch 00007: val_loss did not improve from 0.00411
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0067 - val_loss: 0.0046
# Epoch 8/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.1373
# Epoch 00008: val_loss did not improve from 0.00411
# 144/144 [==============================] - 5s 36ms/step - loss: 0.1373 - val_loss: 0.0087
# Epoch 9/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0448
# Epoch 00009: val_loss did not improve from 0.00411
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0445 - val_loss: 0.0047
# Epoch 10/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0056
# Epoch 00010: val_loss did not improve from 0.00411
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0056 - val_loss: 0.0048
# Epoch 11/150
# 142/144 [============================>.] - ETA: 0s - loss: 0.0069
# Epoch 00011: val_loss did not improve from 0.00411
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0070 - val_loss: 0.0044
# Epoch 12/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0088
# Epoch 00012: val_loss did not improve from 0.00411
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0088 - val_loss: 0.0045
# Epoch 13/150
# 142/144 [============================>.] - ETA: 0s - loss: 0.0062
# Epoch 00013: val_loss did not improve from 0.00411
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0063 - val_loss: 0.0042
# Epoch 14/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0049
# Epoch 00014: val_loss did not improve from 0.00411
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0049 - val_loss: 0.0043
# Epoch 15/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0048
# Epoch 00015: val_loss did not improve from 0.00411
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0048 - val_loss: 0.0045
# Epoch 16/150
# 142/144 [============================>.] - ETA: 0s - loss: 0.0893
# Epoch 00016: val_loss did not improve from 0.00411
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0900 - val_loss: 0.0073
# Epoch 17/150
# 142/144 [============================>.] - ETA: 0s - loss: 0.0768
# Epoch 00017: val_loss did not improve from 0.00411
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0758 - val_loss: 0.0044
# Epoch 18/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0054
# Epoch 00018: val_loss did not improve from 0.00411
# 144/144 [==============================] - 5s 35ms/step - loss: 0.0055 - val_loss: 0.0043
# Epoch 19/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0061
# Epoch 00019: val_loss did not improve from 0.00411
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0061 - val_loss: 0.0042
# Epoch 20/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0088
# Epoch 00020: val_loss did not improve from 0.00411
# 144/144 [==============================] - 5s 35ms/step - loss: 0.0088 - val_loss: 0.0041
# Epoch 21/150
# 142/144 [============================>.] - ETA: 0s - loss: 0.0072
# Epoch 00021: val_loss improved from 0.00411 to 0.00393, saving model to ./models/trans_tom_LSTM.h5
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0072 - val_loss: 0.0039
# Epoch 22/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0051
# Epoch 00022: val_loss did not improve from 0.00393
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0051 - val_loss: 0.0043
# Epoch 23/150
# 142/144 [============================>.] - ETA: 0s - loss: 0.0044
# Epoch 00023: val_loss did not improve from 0.00393
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0044 - val_loss: 0.0043
# Epoch 24/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0535
# Epoch 00024: val_loss did not improve from 0.00393
# 144/144 [==============================] - 5s 35ms/step - loss: 0.0539 - val_loss: 0.0047
# Epoch 25/150
# 142/144 [============================>.] - ETA: 0s - loss: 0.1056
# Epoch 00025: val_loss did not improve from 0.00393
# 144/144 [==============================] - 5s 36ms/step - loss: 0.1042 - val_loss: 0.0043
# Epoch 26/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0054
# Epoch 00026: val_loss did not improve from 0.00393
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0054 - val_loss: 0.0042
# Epoch 27/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0060
# Epoch 00027: val_loss did not improve from 0.00393
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0060 - val_loss: 0.0043
# Epoch 28/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0082
# Epoch 00028: val_loss did not improve from 0.00393
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0083 - val_loss: 0.0043
# Epoch 29/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0076
# Epoch 00029: val_loss did not improve from 0.00393
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0076 - val_loss: 0.0040
# Epoch 30/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0053
# Epoch 00030: val_loss did not improve from 0.00393
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0053 - val_loss: 0.0042
# Epoch 31/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0044
# Epoch 00031: val_loss did not improve from 0.00393
# 144/144 [==============================] - 5s 35ms/step - loss: 0.0044 - val_loss: 0.0043
# Epoch 32/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0187
# Epoch 00032: val_loss did not improve from 0.00393
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0199 - val_loss: 0.0046
# Epoch 33/150
# 142/144 [============================>.] - ETA: 0s - loss: 0.1321
# Epoch 00033: val_loss did not improve from 0.00393
# 144/144 [==============================] - 5s 36ms/step - loss: 0.1303 - val_loss: 0.0046
# Epoch 34/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0056
# Epoch 00034: val_loss did not improve from 0.00393
# 144/144 [==============================] - 5s 35ms/step - loss: 0.0056 - val_loss: 0.0045
# Epoch 35/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0057
# Epoch 00035: val_loss did not improve from 0.00393
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0057 - val_loss: 0.0042
# Epoch 36/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0076
# Epoch 00036: val_loss did not improve from 0.00393
# 144/144 [==============================] - 5s 35ms/step - loss: 0.0076 - val_loss: 0.0041
# Epoch 37/150
# 142/144 [============================>.] - ETA: 0s - loss: 0.0082
# Epoch 00037: val_loss did not improve from 0.00393
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0082 - val_loss: 0.0040
# Epoch 38/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0056
# Epoch 00038: val_loss did not improve from 0.00393
# 144/144 [==============================] - 5s 35ms/step - loss: 0.0056 - val_loss: 0.0042
# Epoch 39/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0047
# Epoch 00039: val_loss did not improve from 0.00393
# 144/144 [==============================] - 5s 36ms/step - loss: 0.0047 - val_loss: 0.0043
# Epoch 40/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0067
# Epoch 00040: val_loss did not improve from 0.00393
# 144/144 [==============================] - 5s 35ms/step - loss: 0.0068 - val_loss: 0.0050
# Epoch 41/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.1148
# Epoch 00041: val_loss did not improve from 0.00393
# 144/144 [==============================] - 5s 35ms/step - loss: 0.1154 - val_loss: 0.0062

# %%
raw_lstm_model = tf.keras.models.Sequential([
    tf.keras.layers.LSTM(N_HIDDEN, input_shape=train_input.shape[-2:], return_sequences=True),
    tf.keras.layers.LayerNormalization(), # TEST
    tf.keras.layers.Dense(test_label.shape[-1])
])

# %%
raw_lstm_model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
                   loss = tf.keras.losses.MeanSquaredError())

# %%
callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        filepath=RAW_BEST_PATHS[1],
        save_best_only=True,
        monitor='val_loss',
        verbose=1),
    tf.keras.callbacks.EarlyStopping(
  monitor='val_loss', min_delta=0.0001,  patience=20)
]

# %%
raw_lstm_model.fit(
    train_dataset, epochs = 150,
    steps_per_epoch = 144,
    callbacks=callbacks,
    validation_data = test_dataset, validation_steps = 50)
# Out:
# Train for 144 steps, validate for 50 steps
# Epoch 1/150
# 141/144 [============================>.] - ETA: 0s - loss: 0.0580
# Epoch 00001: val_loss improved from inf to 0.00546, saving model to ./models/raw_tom_LSTM.h5
# 144/144 [==============================] - 5s 34ms/step - loss: 0.0569 - val_loss: 0.0055
# Epoch 2/150
# 138/144 [===========================>..] - ETA: 0s - loss: 0.0079
# Epoch 00002: val_loss did not improve from 0.00546
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0079 - val_loss: 0.0055
# Epoch 3/150
# 139/144 [===========================>..] - ETA: 0s - loss: 0.0094
# Epoch 00003: val_loss did not improve from 0.00546
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0095 - val_loss: 0.0059
# Epoch 4/150
# 138/144 [===========================>..] - ETA: 0s - loss: 0.0106
# Epoch 00004: val_loss did not improve from 0.00546
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0105 - val_loss: 0.0055
# Epoch 5/150
# 139/144 [===========================>..] - ETA: 0s - loss: 0.0070
# Epoch 00005: val_loss improved from 0.00546 to 0.00486, saving model to ./models/raw_tom_LSTM.h5
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0070 - val_loss: 0.0049
# Epoch 6/150
# 139/144 [===========================>..] - ETA: 0s - loss: 0.0059
# Epoch 00006: val_loss did not improve from 0.00486
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0060 - val_loss: 0.0054
# Epoch 7/150
# 138/144 [===========================>..] - ETA: 0s - loss: 0.0119
# Epoch 00007: val_loss did not improve from 0.00486
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0122 - val_loss: 0.0080
# Epoch 8/150
# 139/144 [===========================>..] - ETA: 0s - loss: 0.1517
# Epoch 00008: val_loss did not improve from 0.00486
# 144/144 [==============================] - 2s 12ms/step - loss: 0.1527 - val_loss: 0.0084
# Epoch 9/150
# 138/144 [===========================>..] - ETA: 0s - loss: 0.0435
# Epoch 00009: val_loss did not improve from 0.00486
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0419 - val_loss: 0.0052
# Epoch 10/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0064
# Epoch 00010: val_loss did not improve from 0.00486
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0064 - val_loss: 0.0049
# Epoch 11/150
# 142/144 [============================>.] - ETA: 0s - loss: 0.0074
# Epoch 00011: val_loss did not improve from 0.00486
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0074 - val_loss: 0.0059
# Epoch 12/150
# 139/144 [===========================>..] - ETA: 0s - loss: 0.0106
# Epoch 00012: val_loss did not improve from 0.00486
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0106 - val_loss: 0.0060
# Epoch 13/150
# 139/144 [===========================>..] - ETA: 0s - loss: 0.0073
# Epoch 00013: val_loss improved from 0.00486 to 0.00469, saving model to ./models/raw_tom_LSTM.h5
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0072 - val_loss: 0.0047
# Epoch 14/150
# 139/144 [===========================>..] - ETA: 0s - loss: 0.0057
# Epoch 00014: val_loss improved from 0.00469 to 0.00462, saving model to ./models/raw_tom_LSTM.h5
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0057 - val_loss: 0.0046
# Epoch 15/150
# 139/144 [===========================>..] - ETA: 0s - loss: 0.0056
# Epoch 00015: val_loss did not improve from 0.00462
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0057 - val_loss: 0.0058
# Epoch 16/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0874
# Epoch 00016: val_loss did not improve from 0.00462
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0879 - val_loss: 0.0089
# Epoch 17/150
# 138/144 [===========================>..] - ETA: 0s - loss: 0.0792
# Epoch 00017: val_loss improved from 0.00462 to 0.00448, saving model to ./models/raw_tom_LSTM.h5
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0761 - val_loss: 0.0045
# Epoch 18/150
# 138/144 [===========================>..] - ETA: 0s - loss: 0.0060
# Epoch 00018: val_loss improved from 0.00448 to 0.00447, saving model to ./models/raw_tom_LSTM.h5
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0060 - val_loss: 0.0045
# Epoch 19/150
# 139/144 [===========================>..] - ETA: 0s - loss: 0.0067
# Epoch 00019: val_loss did not improve from 0.00447
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0067 - val_loss: 0.0049
# Epoch 20/150
# 139/144 [===========================>..] - ETA: 0s - loss: 0.0098
# Epoch 00020: val_loss did not improve from 0.00447
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0097 - val_loss: 0.0046
# Epoch 21/150
# 138/144 [===========================>..] - ETA: 0s - loss: 0.0080
# Epoch 00021: val_loss did not improve from 0.00447
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0079 - val_loss: 0.0045
# Epoch 22/150
# 138/144 [===========================>..] - ETA: 0s - loss: 0.0058
# Epoch 00022: val_loss did not improve from 0.00447
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0057 - val_loss: 0.0045
# Epoch 23/150
# 139/144 [===========================>..] - ETA: 0s - loss: 0.0049
# Epoch 00023: val_loss did not improve from 0.00447
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0049 - val_loss: 0.0048
# Epoch 24/150
# 139/144 [===========================>..] - ETA: 0s - loss: 0.0449
# Epoch 00024: val_loss did not improve from 0.00447
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0479 - val_loss: 0.0140
# Epoch 25/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.1013
# Epoch 00025: val_loss did not improve from 0.00447
# 144/144 [==============================] - 2s 12ms/step - loss: 0.1006 - val_loss: 0.0048
# Epoch 26/150
# 139/144 [===========================>..] - ETA: 0s - loss: 0.0062
# Epoch 00026: val_loss did not improve from 0.00447
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0062 - val_loss: 0.0057
# Epoch 27/150
# 139/144 [===========================>..] - ETA: 0s - loss: 0.0065
# Epoch 00027: val_loss did not improve from 0.00447
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0065 - val_loss: 0.0047
# Epoch 28/150
# 138/144 [===========================>..] - ETA: 0s - loss: 0.0092
# Epoch 00028: val_loss did not improve from 0.00447
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0092 - val_loss: 0.0051
# Epoch 29/150
# 139/144 [===========================>..] - ETA: 0s - loss: 0.0090
# Epoch 00029: val_loss did not improve from 0.00447
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0089 - val_loss: 0.0047
# Epoch 30/150
# 139/144 [===========================>..] - ETA: 0s - loss: 0.0059
# Epoch 00030: val_loss did not improve from 0.00447
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0059 - val_loss: 0.0048
# Epoch 31/150
# 139/144 [===========================>..] - ETA: 0s - loss: 0.0050
# Epoch 00031: val_loss did not improve from 0.00447
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0049 - val_loss: 0.0051
# Epoch 32/150
# 139/144 [===========================>..] - ETA: 0s - loss: 0.0170
# Epoch 00032: val_loss did not improve from 0.00447
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0190 - val_loss: 0.0069
# Epoch 33/150
# 138/144 [===========================>..] - ETA: 0s - loss: 0.1263
# Epoch 00033: val_loss did not improve from 0.00447
# 144/144 [==============================] - 2s 12ms/step - loss: 0.1215 - val_loss: 0.0048
# Epoch 34/150
# 139/144 [===========================>..] - ETA: 0s - loss: 0.0059
# Epoch 00034: val_loss did not improve from 0.00447
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0059 - val_loss: 0.0049
# Epoch 35/150
# 138/144 [===========================>..] - ETA: 0s - loss: 0.0061
# Epoch 00035: val_loss did not improve from 0.00447
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0062 - val_loss: 0.0045
# Epoch 36/150
# 139/144 [===========================>..] - ETA: 0s - loss: 0.0085
# Epoch 00036: val_loss did not improve from 0.00447
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0086 - val_loss: 0.0050
# Epoch 37/150
# 138/144 [===========================>..] - ETA: 0s - loss: 0.0092
# Epoch 00037: val_loss improved from 0.00447 to 0.00434, saving model to ./models/raw_tom_LSTM.h5
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0091 - val_loss: 0.0043
# Epoch 38/150
# 139/144 [===========================>..] - ETA: 0s - loss: 0.0061
# Epoch 00038: val_loss improved from 0.00434 to 0.00422, saving model to ./models/raw_tom_LSTM.h5
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0061 - val_loss: 0.0042
# Epoch 39/150
# 139/144 [===========================>..] - ETA: 0s - loss: 0.0050
# Epoch 00039: val_loss did not improve from 0.00422
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0050 - val_loss: 0.0047
# Epoch 40/150
# 139/144 [===========================>..] - ETA: 0s - loss: 0.0067
# Epoch 00040: val_loss did not improve from 0.00422
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0071 - val_loss: 0.0049
# Epoch 41/150
# 138/144 [===========================>..] - ETA: 0s - loss: 0.1055
# Epoch 00041: val_loss did not improve from 0.00422
# 144/144 [==============================] - 2s 12ms/step - loss: 0.1080 - val_loss: 0.0063
# Epoch 42/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0283
# Epoch 00042: val_loss did not improve from 0.00422
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0281 - val_loss: 0.0043
# Epoch 43/150
# 138/144 [===========================>..] - ETA: 0s - loss: 0.0057
# Epoch 00043: val_loss did not improve from 0.00422
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0057 - val_loss: 0.0046
# Epoch 44/150
# 138/144 [===========================>..] - ETA: 0s - loss: 0.0076
# Epoch 00044: val_loss did not improve from 0.00422
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0076 - val_loss: 0.0051
# Epoch 45/150
# 139/144 [===========================>..] - ETA: 0s - loss: 0.0092
# Epoch 00045: val_loss did not improve from 0.00422
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0092 - val_loss: 0.0043
# Epoch 46/150
# 139/144 [===========================>..] - ETA: 0s - loss: 0.0068
# Epoch 00046: val_loss improved from 0.00422 to 0.00420, saving model to ./models/raw_tom_LSTM.h5
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0068 - val_loss: 0.0042
# Epoch 47/150
# 138/144 [===========================>..] - ETA: 0s - loss: 0.0052
# Epoch 00047: val_loss did not improve from 0.00420
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0052 - val_loss: 0.0044
# Epoch 48/150
# 139/144 [===========================>..] - ETA: 0s - loss: 0.0050
# Epoch 00048: val_loss did not improve from 0.00420
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0053 - val_loss: 0.0063
# Epoch 49/150
# 138/144 [===========================>..] - ETA: 0s - loss: 0.0786
# Epoch 00049: val_loss did not improve from 0.00420
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0812 - val_loss: 0.0089
# Epoch 50/150
# 139/144 [===========================>..] - ETA: 0s - loss: 0.0580
# Epoch 00050: val_loss did not improve from 0.00420
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0562 - val_loss: 0.0043
# Epoch 51/150
# 139/144 [===========================>..] - ETA: 0s - loss: 0.0056
# Epoch 00051: val_loss did not improve from 0.00420
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0056 - val_loss: 0.0044
# Epoch 52/150
# 139/144 [===========================>..] - ETA: 0s - loss: 0.0064
# Epoch 00052: val_loss did not improve from 0.00420
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0064 - val_loss: 0.0043
# Epoch 53/150
# 138/144 [===========================>..] - ETA: 0s - loss: 0.0091
# Epoch 00053: val_loss did not improve from 0.00420
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0091 - val_loss: 0.0051
# Epoch 54/150
# 138/144 [===========================>..] - ETA: 0s - loss: 0.0075
# Epoch 00054: val_loss improved from 0.00420 to 0.00414, saving model to ./models/raw_tom_LSTM.h5
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0075 - val_loss: 0.0041
# Epoch 55/150
# 138/144 [===========================>..] - ETA: 0s - loss: 0.0052
# Epoch 00055: val_loss did not improve from 0.00414
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0051 - val_loss: 0.0042
# Epoch 56/150
# 139/144 [===========================>..] - ETA: 0s - loss: 0.0045
# Epoch 00056: val_loss did not improve from 0.00414
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0045 - val_loss: 0.0048
# Epoch 57/150
# 139/144 [===========================>..] - ETA: 0s - loss: 0.0426
# Epoch 00057: val_loss did not improve from 0.00414
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0462 - val_loss: 0.0046
# Epoch 58/150
# 138/144 [===========================>..] - ETA: 0s - loss: 0.0879
# Epoch 00058: val_loss did not improve from 0.00414
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0845 - val_loss: 0.0047

# %% [markdown]
# ### Model evaluation

# %%
lstm_model = tf.keras.models.load_model(BEST_PATHS[1])
trans_lstm_model = tf.keras.models.load_model(TRANS_BEST_PATHS[1])
raw_lstm_model = tf.keras.models.load_model(RAW_BEST_PATHS[1])

# %%
lstm_pred = lstm_model.predict(test_dataset)
trans_lstm_pred = trans_lstm_model.predict(test_dataset)
raw_lstm_pred = raw_lstm_model.predict(test_dataset)

# %%
fig = plt.figure(figsize=((6/2.54)*4, (6/2.54)*4))

plt.scatter(tf.cast(tf.reshape(((MAXS-MINS)*test_label + MINS)[:, :, 0], (-1, 1)), tf.float32),
            tf.cast(tf.reshape(((MAXS-MINS)*lstm_pred + MINS)[:, :, 0], (-1, 1)), tf.float32),
            c=cmap[3], s=2, alpha=0.3
           )
plt.scatter(tf.cast(tf.reshape(((MAXS-MINS)*test_label + MINS)[:, :, 0], (-1, 1)), tf.float32),
            tf.cast(tf.reshape(((MAXS-MINS)*raw_lstm_pred + MINS)[:, :, 0], (-1, 1)), tf.float32),
            c=cmap[4], s=2, alpha=0.3
           )
plt.scatter(tf.cast(tf.reshape(((MAXS-MINS)*test_label + MINS)[:, :, 0], (-1, 1)), tf.float32),
            tf.cast(tf.reshape(((MAXS-MINS)*trans_lstm_pred + MINS)[:, :, 0], (-1, 1)), tf.float32),
            c=cmap[0], s=2, alpha=0.3
           )
plt.axis([-10,50,-10,50])
# Out:
# [-10, 50, -10, 50]

# %%
x_t = np.arange(0, test_label.shape[1])
for _ in range (6):

        NUMBERS = np.arange(1, lstm_pred.shape[0])
        np.random.shuffle(NUMBERS)
        NUMBERS = NUMBERS[:6]
        position = 331
        fig = plt.figure(figsize=((8.5/2.54)*4, (6/2.54)*4))
        
        i=0
        for NUMBER in NUMBERS:
            ax = plt.subplot(position)
            measured1 = plt.plot(x_t, test_label[NUMBER, :, i], c='k', alpha=1) #measured
            expect1 = plt.plot(x_t, lstm_pred[NUMBER, :, i], c=cmap[3], alpha=0.8) #estimated
            expect1 = plt.plot(x_t, raw_lstm_pred[NUMBER, :, i], c=cmap[4], alpha=0.8) #estimated
            expect1 = plt.plot(x_t, trans_lstm_pred[NUMBER, :, i], c=cmap[0], alpha=0.8) #estimated
            ax.axis('off')

            position += 1
        plt.show()
        _ += 1

# %% [markdown]
# # Transfer learning - BiLSTM

# %%
bilstm_model_copy = tf.keras.models.load_model(BEST_PATHS[3])
bilstm_model_copy.trainable = False

# %%
trans_bilstm_model = tf.keras.Sequential([bilstm_model_copy.get_layer(index=0), 
                                          bilstm_model_copy.get_layer(index=1),
                                          bilstm_model_copy.get_layer(index=2),
                                          bilstm_model_copy.get_layer(index=3),
                                       tf.keras.layers.Dense(test_label.shape[-1], name='retrain_dense')])

# %%
trans_bilstm_model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
                   loss = tf.keras.losses.MeanSquaredError())

# %%
callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        filepath=TRANS_BEST_PATHS[3],
        save_best_only=True,
        monitor='val_loss',
        verbose=1),
    tf.keras.callbacks.EarlyStopping(
  monitor='val_loss', min_delta=0.0001,  patience=20)
]

# %%
trans_bilstm_model.fit(
    train_dataset, epochs = 150,
    steps_per_epoch = 144,
    callbacks=callbacks,
    validation_data = test_dataset, validation_steps = 50)
# Out:
# Train for 144 steps, validate for 50 steps
# Epoch 1/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.1825
# Epoch 00001: val_loss improved from inf to 0.02071, saving model to ./models/trans_tom_BiLSTM.h5
# 144/144 [==============================] - 18s 126ms/step - loss: 0.1814 - val_loss: 0.0207
# Epoch 2/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0218
# Epoch 00002: val_loss improved from 0.02071 to 0.01232, saving model to ./models/trans_tom_BiLSTM.h5
# 144/144 [==============================] - 14s 94ms/step - loss: 0.0218 - val_loss: 0.0123
# Epoch 3/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0157
# Epoch 00003: val_loss improved from 0.01232 to 0.01063, saving model to ./models/trans_tom_BiLSTM.h5
# 144/144 [==============================] - 14s 95ms/step - loss: 0.0157 - val_loss: 0.0106
# Epoch 4/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0135
# Epoch 00004: val_loss improved from 0.01063 to 0.00718, saving model to ./models/trans_tom_BiLSTM.h5
# 144/144 [==============================] - 14s 96ms/step - loss: 0.0135 - val_loss: 0.0072
# Epoch 5/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0088
# Epoch 00005: val_loss improved from 0.00718 to 0.00677, saving model to ./models/trans_tom_BiLSTM.h5
# 144/144 [==============================] - 14s 95ms/step - loss: 0.0088 - val_loss: 0.0068
# Epoch 6/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0070
# Epoch 00006: val_loss improved from 0.00677 to 0.00587, saving model to ./models/trans_tom_BiLSTM.h5
# 144/144 [==============================] - 14s 95ms/step - loss: 0.0070 - val_loss: 0.0059
# Epoch 7/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0319
# Epoch 00007: val_loss did not improve from 0.00587
# 144/144 [==============================] - 14s 94ms/step - loss: 0.0323 - val_loss: 0.0437
# Epoch 8/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.4697
# Epoch 00008: val_loss did not improve from 0.00587
# 144/144 [==============================] - 14s 95ms/step - loss: 0.4702 - val_loss: 0.0264
# Epoch 9/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.1260
# Epoch 00009: val_loss did not improve from 0.00587
# 144/144 [==============================] - 14s 96ms/step - loss: 0.1252 - val_loss: 0.0086
# Epoch 10/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0130
# Epoch 00010: val_loss did not improve from 0.00587
# 144/144 [==============================] - 14s 94ms/step - loss: 0.0130 - val_loss: 0.0070
# Epoch 11/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0114
# Epoch 00011: val_loss did not improve from 0.00587
# 144/144 [==============================] - 14s 96ms/step - loss: 0.0114 - val_loss: 0.0069
# Epoch 12/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0125
# Epoch 00012: val_loss improved from 0.00587 to 0.00548, saving model to ./models/trans_tom_BiLSTM.h5
# 144/144 [==============================] - 14s 95ms/step - loss: 0.0124 - val_loss: 0.0055
# Epoch 13/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0085
# Epoch 00013: val_loss did not improve from 0.00548
# 144/144 [==============================] - 14s 94ms/step - loss: 0.0085 - val_loss: 0.0074
# Epoch 14/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0072
# Epoch 00014: val_loss did not improve from 0.00548
# 144/144 [==============================] - 14s 96ms/step - loss: 0.0072 - val_loss: 0.0065
# Epoch 15/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0084
# Epoch 00015: val_loss did not improve from 0.00548
# 144/144 [==============================] - 14s 97ms/step - loss: 0.0084 - val_loss: 0.0105
# Epoch 16/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.2362
# Epoch 00016: val_loss did not improve from 0.00548
# 144/144 [==============================] - 14s 95ms/step - loss: 0.2380 - val_loss: 0.0129
# Epoch 17/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.1935
# Epoch 00017: val_loss did not improve from 0.00548
# 144/144 [==============================] - 14s 96ms/step - loss: 0.1922 - val_loss: 0.0082
# Epoch 18/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0107
# Epoch 00018: val_loss did not improve from 0.00548
# 144/144 [==============================] - 14s 95ms/step - loss: 0.0107 - val_loss: 0.0059
# Epoch 19/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0103
# Epoch 00019: val_loss did not improve from 0.00548
# 144/144 [==============================] - 14s 96ms/step - loss: 0.0103 - val_loss: 0.0064
# Epoch 20/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0120
# Epoch 00020: val_loss did not improve from 0.00548
# 144/144 [==============================] - 14s 95ms/step - loss: 0.0120 - val_loss: 0.0058
# Epoch 21/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0091
# Epoch 00021: val_loss did not improve from 0.00548
# 144/144 [==============================] - 14s 97ms/step - loss: 0.0091 - val_loss: 0.0056
# Epoch 22/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0068
# Epoch 00022: val_loss did not improve from 0.00548
# 144/144 [==============================] - 14s 95ms/step - loss: 0.0068 - val_loss: 0.0061
# Epoch 23/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0063
# Epoch 00023: val_loss did not improve from 0.00548
# 144/144 [==============================] - 13s 93ms/step - loss: 0.0063 - val_loss: 0.0060
# Epoch 24/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.1131
# Epoch 00024: val_loss did not improve from 0.00548
# 144/144 [==============================] - 14s 96ms/step - loss: 0.1144 - val_loss: 0.0092
# Epoch 25/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.2431
# Epoch 00025: val_loss did not improve from 0.00548
# 144/144 [==============================] - 14s 94ms/step - loss: 0.2415 - val_loss: 0.0072
# Epoch 26/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0095
# Epoch 00026: val_loss did not improve from 0.00548
# 144/144 [==============================] - 14s 96ms/step - loss: 0.0095 - val_loss: 0.0057
# Epoch 27/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0097
# Epoch 00027: val_loss did not improve from 0.00548
# 144/144 [==============================] - 14s 94ms/step - loss: 0.0097 - val_loss: 0.0057
# Epoch 28/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0109
# Epoch 00028: val_loss did not improve from 0.00548
# 144/144 [==============================] - 14s 95ms/step - loss: 0.0110 - val_loss: 0.0058
# Epoch 29/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0095
# Epoch 00029: val_loss improved from 0.00548 to 0.00511, saving model to ./models/trans_tom_BiLSTM.h5
# 144/144 [==============================] - 14s 95ms/step - loss: 0.0095 - val_loss: 0.0051
# Epoch 30/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 00030: val_loss improved from 0.00511 to 0.00509, saving model to ./models/trans_tom_BiLSTM.h5
# 144/144 [==============================] - 14s 96ms/step - loss: 0.0071 - val_loss: 0.0051
# Epoch 31/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0061
# Epoch 00031: val_loss did not improve from 0.00509
# 144/144 [==============================] - 14s 95ms/step - loss: 0.0061 - val_loss: 0.0056
# Epoch 32/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0303
# Epoch 00032: val_loss did not improve from 0.00509
# 144/144 [==============================] - 14s 95ms/step - loss: 0.0326 - val_loss: 0.0070
# Epoch 33/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.2818
# Epoch 00033: val_loss did not improve from 0.00509
# 144/144 [==============================] - 14s 95ms/step - loss: 0.2799 - val_loss: 0.0089
# Epoch 34/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0091
# Epoch 00034: val_loss did not improve from 0.00509
# 144/144 [==============================] - 14s 95ms/step - loss: 0.0091 - val_loss: 0.0060
# Epoch 35/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0090
# Epoch 00035: val_loss did not improve from 0.00509
# 144/144 [==============================] - 14s 96ms/step - loss: 0.0090 - val_loss: 0.0059
# Epoch 36/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0100
# Epoch 00036: val_loss did not improve from 0.00509
# 144/144 [==============================] - 14s 96ms/step - loss: 0.0101 - val_loss: 0.0057
# Epoch 37/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0102
# Epoch 00037: val_loss improved from 0.00509 to 0.00495, saving model to ./models/trans_tom_BiLSTM.h5
# 144/144 [==============================] - 14s 94ms/step - loss: 0.0102 - val_loss: 0.0049
# Epoch 38/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 00038: val_loss improved from 0.00495 to 0.00493, saving model to ./models/trans_tom_BiLSTM.h5
# 144/144 [==============================] - 14s 96ms/step - loss: 0.0071 - val_loss: 0.0049
# Epoch 39/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0062
# Epoch 00039: val_loss did not improve from 0.00493
# 144/144 [==============================] - 14s 97ms/step - loss: 0.0062 - val_loss: 0.0053
# Epoch 40/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0112
# Epoch 00040: val_loss did not improve from 0.00493
# 144/144 [==============================] - 14s 96ms/step - loss: 0.0113 - val_loss: 0.0060
# Epoch 41/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.2277
# Epoch 00041: val_loss did not improve from 0.00493
# 144/144 [==============================] - 14s 94ms/step - loss: 0.2280 - val_loss: 0.0079
# Epoch 42/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0547
# Epoch 00042: val_loss did not improve from 0.00493
# 144/144 [==============================] - 14s 95ms/step - loss: 0.0544 - val_loss: 0.0053
# Epoch 43/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0081
# Epoch 00043: val_loss did not improve from 0.00493
# 144/144 [==============================] - 14s 94ms/step - loss: 0.0081 - val_loss: 0.0052
# Epoch 44/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0092
# Epoch 00044: val_loss did not improve from 0.00493
# 144/144 [==============================] - 14s 95ms/step - loss: 0.0092 - val_loss: 0.0055
# Epoch 45/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0104
# Epoch 00045: val_loss did not improve from 0.00493
# 144/144 [==============================] - 14s 96ms/step - loss: 0.0104 - val_loss: 0.0050
# Epoch 46/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0075
# Epoch 00046: val_loss improved from 0.00493 to 0.00482, saving model to ./models/trans_tom_BiLSTM.h5
# 144/144 [==============================] - 14s 95ms/step - loss: 0.0075 - val_loss: 0.0048
# Epoch 47/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0063
# Epoch 00047: val_loss did not improve from 0.00482
# 144/144 [==============================] - 14s 95ms/step - loss: 0.0063 - val_loss: 0.0051
# Epoch 48/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0076
# Epoch 00048: val_loss did not improve from 0.00482
# 144/144 [==============================] - 14s 96ms/step - loss: 0.0077 - val_loss: 0.0057
# Epoch 49/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.1558
# Epoch 00049: val_loss did not improve from 0.00482
# 144/144 [==============================] - 14s 96ms/step - loss: 0.1572 - val_loss: 0.0083
# Epoch 50/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.1102
# Epoch 00050: val_loss did not improve from 0.00482
# 144/144 [==============================] - 14s 96ms/step - loss: 0.1095 - val_loss: 0.0055
# Epoch 51/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0076
# Epoch 00051: val_loss did not improve from 0.00482
# 144/144 [==============================] - 14s 96ms/step - loss: 0.0076 - val_loss: 0.0054
# Epoch 52/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0082
# Epoch 00052: val_loss did not improve from 0.00482
# 144/144 [==============================] - 14s 96ms/step - loss: 0.0083 - val_loss: 0.0051
# Epoch 53/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0106
# Epoch 00053: val_loss did not improve from 0.00482
# 144/144 [==============================] - 14s 95ms/step - loss: 0.0106 - val_loss: 0.0051
# Epoch 54/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0080
# Epoch 00054: val_loss did not improve from 0.00482
# 144/144 [==============================] - 14s 95ms/step - loss: 0.0080 - val_loss: 0.0049
# Epoch 55/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0065
# Epoch 00055: val_loss did not improve from 0.00482
# 144/144 [==============================] - 14s 95ms/step - loss: 0.0065 - val_loss: 0.0052
# Epoch 56/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0060
# Epoch 00056: val_loss did not improve from 0.00482
# 144/144 [==============================] - 14s 95ms/step - loss: 0.0060 - val_loss: 0.0054
# Epoch 57/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0899
# Epoch 00057: val_loss did not improve from 0.00482
# 144/144 [==============================] - 14s 95ms/step - loss: 0.0908 - val_loss: 0.0062
# Epoch 58/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.1645
# Epoch 00058: val_loss did not improve from 0.00482
# 144/144 [==============================] - 13s 93ms/step - loss: 0.1634 - val_loss: 0.0059
# Epoch 59/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0072
# Epoch 00059: val_loss did not improve from 0.00482
# 144/144 [==============================] - 14s 95ms/step - loss: 0.0072 - val_loss: 0.0050
# Epoch 60/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0079
# Epoch 00060: val_loss did not improve from 0.00482
# 144/144 [==============================] - 14s 95ms/step - loss: 0.0079 - val_loss: 0.0050
# Epoch 61/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0099
# Epoch 00061: val_loss did not improve from 0.00482
# 144/144 [==============================] - 14s 95ms/step - loss: 0.0099 - val_loss: 0.0052
# Epoch 62/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0085
# Epoch 00062: val_loss improved from 0.00482 to 0.00462, saving model to ./models/trans_tom_BiLSTM.h5
# 144/144 [==============================] - 14s 95ms/step - loss: 0.0085 - val_loss: 0.0046
# Epoch 63/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0065
# Epoch 00063: val_loss did not improve from 0.00462
# 144/144 [==============================] - 14s 94ms/step - loss: 0.0065 - val_loss: 0.0047
# Epoch 64/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0057
# Epoch 00064: val_loss did not improve from 0.00462
# 144/144 [==============================] - 14s 96ms/step - loss: 0.0057 - val_loss: 0.0052
# Epoch 65/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0380
# Epoch 00065: val_loss did not improve from 0.00462
# 144/144 [==============================] - 14s 94ms/step - loss: 0.0386 - val_loss: 0.0058
# Epoch 66/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.2070
# Epoch 00066: val_loss did not improve from 0.00462
# 144/144 [==============================] - 14s 95ms/step - loss: 0.2056 - val_loss: 0.0063
# Epoch 67/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 00067: val_loss did not improve from 0.00462
# 144/144 [==============================] - 14s 95ms/step - loss: 0.0071 - val_loss: 0.0053
# Epoch 68/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0075
# Epoch 00068: val_loss did not improve from 0.00462
# 144/144 [==============================] - 14s 96ms/step - loss: 0.0075 - val_loss: 0.0049
# Epoch 69/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0090
# Epoch 00069: val_loss did not improve from 0.00462
# 144/144 [==============================] - 14s 96ms/step - loss: 0.0090 - val_loss: 0.0049
# Epoch 70/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0094
# Epoch 00070: val_loss did not improve from 0.00462
# 144/144 [==============================] - 14s 96ms/step - loss: 0.0094 - val_loss: 0.0046
# Epoch 71/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0068
# Epoch 00071: val_loss did not improve from 0.00462
# 144/144 [==============================] - 14s 96ms/step - loss: 0.0068 - val_loss: 0.0047
# Epoch 72/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0060
# Epoch 00072: val_loss did not improve from 0.00462
# 144/144 [==============================] - 14s 97ms/step - loss: 0.0060 - val_loss: 0.0049
# Epoch 73/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0136
# Epoch 00073: val_loss did not improve from 0.00462
# 144/144 [==============================] - 14s 95ms/step - loss: 0.0138 - val_loss: 0.0055
# Epoch 74/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.1972
# Epoch 00074: val_loss did not improve from 0.00462
# 144/144 [==============================] - 14s 96ms/step - loss: 0.1973 - val_loss: 0.0075
# Epoch 75/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0334
# Epoch 00075: val_loss did not improve from 0.00462
# 144/144 [==============================] - 14s 94ms/step - loss: 0.0332 - val_loss: 0.0048
# Epoch 76/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0069
# Epoch 00076: val_loss did not improve from 0.00462
# 144/144 [==============================] - 14s 96ms/step - loss: 0.0069 - val_loss: 0.0049
# Epoch 77/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0084
# Epoch 00077: val_loss did not improve from 0.00462
# 144/144 [==============================] - 14s 95ms/step - loss: 0.0084 - val_loss: 0.0050
# Epoch 78/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0098
# Epoch 00078: val_loss did not improve from 0.00462
# 144/144 [==============================] - 14s 95ms/step - loss: 0.0098 - val_loss: 0.0049
# Epoch 79/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 00079: val_loss did not improve from 0.00462
# 144/144 [==============================] - 14s 95ms/step - loss: 0.0071 - val_loss: 0.0046
# Epoch 80/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0062
# Epoch 00080: val_loss did not improve from 0.00462
# 144/144 [==============================] - 14s 96ms/step - loss: 0.0062 - val_loss: 0.0047
# Epoch 81/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0080
# Epoch 00081: val_loss did not improve from 0.00462
# 144/144 [==============================] - 14s 95ms/step - loss: 0.0081 - val_loss: 0.0053
# Epoch 82/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.1439
# Epoch 00082: val_loss did not improve from 0.00462
# 144/144 [==============================] - 14s 94ms/step - loss: 0.1446 - val_loss: 0.0062

# %%
trans_bilstm_model = tf.keras.models.load_model(TRANS_BEST_PATHS[3])
trans_bilstm_model.trainable = True
trans_bilstm_model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE/10),
                   loss = tf.keras.losses.MeanSquaredError())

# %%
trans_bilstm_model.fit(
    train_dataset, epochs = 150,
    steps_per_epoch = 144,
    callbacks=callbacks,
    validation_data = test_dataset, validation_steps = 50)
# Out:
# Train for 144 steps, validate for 50 steps
# Epoch 1/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0050
# Epoch 00001: val_loss improved from 0.00462 to 0.00360, saving model to ./models/trans_tom_BiLSTM.h5
# 144/144 [==============================] - 19s 131ms/step - loss: 0.0049 - val_loss: 0.0036
# Epoch 2/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0051
# Epoch 00002: val_loss improved from 0.00360 to 0.00346, saving model to ./models/trans_tom_BiLSTM.h5
# 144/144 [==============================] - 14s 96ms/step - loss: 0.0051 - val_loss: 0.0035
# Epoch 3/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0066
# Epoch 00003: val_loss did not improve from 0.00346
# 144/144 [==============================] - 14s 96ms/step - loss: 0.0066 - val_loss: 0.0035
# Epoch 4/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0075
# Epoch 00004: val_loss improved from 0.00346 to 0.00340, saving model to ./models/trans_tom_BiLSTM.h5
# 144/144 [==============================] - 14s 98ms/step - loss: 0.0075 - val_loss: 0.0034
# Epoch 5/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0049
# Epoch 00005: val_loss improved from 0.00340 to 0.00334, saving model to ./models/trans_tom_BiLSTM.h5
# 144/144 [==============================] - 14s 97ms/step - loss: 0.0049 - val_loss: 0.0033
# Epoch 6/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0040
# Epoch 00006: val_loss did not improve from 0.00334
# 144/144 [==============================] - 14s 96ms/step - loss: 0.0040 - val_loss: 0.0039
# Epoch 7/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0070
# Epoch 00007: val_loss did not improve from 0.00334
# 144/144 [==============================] - 14s 97ms/step - loss: 0.0071 - val_loss: 0.0057
# Epoch 8/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.1324
# Epoch 00008: val_loss did not improve from 0.00334
# 144/144 [==============================] - 14s 96ms/step - loss: 0.1327 - val_loss: 0.0045
# Epoch 9/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0347
# Epoch 00009: val_loss did not improve from 0.00334
# 144/144 [==============================] - 14s 95ms/step - loss: 0.0345 - val_loss: 0.0035
# Epoch 10/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0047
# Epoch 00010: val_loss did not improve from 0.00334
# 144/144 [==============================] - 14s 95ms/step - loss: 0.0047 - val_loss: 0.0034
# Epoch 11/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0060
# Epoch 00011: val_loss did not improve from 0.00334
# 144/144 [==============================] - 14s 97ms/step - loss: 0.0061 - val_loss: 0.0034
# Epoch 12/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0075
# Epoch 00012: val_loss did not improve from 0.00334
# 144/144 [==============================] - 14s 96ms/step - loss: 0.0075 - val_loss: 0.0034
# Epoch 13/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0053
# Epoch 00013: val_loss did not improve from 0.00334
# 144/144 [==============================] - 14s 97ms/step - loss: 0.0053 - val_loss: 0.0034
# Epoch 14/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0041
# Epoch 00014: val_loss did not improve from 0.00334
# 144/144 [==============================] - 14s 98ms/step - loss: 0.0041 - val_loss: 0.0036
# Epoch 15/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0040
# Epoch 00015: val_loss did not improve from 0.00334
# 144/144 [==============================] - 14s 97ms/step - loss: 0.0040 - val_loss: 0.0039
# Epoch 16/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0688
# Epoch 00016: val_loss did not improve from 0.00334
# 144/144 [==============================] - 14s 97ms/step - loss: 0.0694 - val_loss: 0.0045
# Epoch 17/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0653
# Epoch 00017: val_loss did not improve from 0.00334
# 144/144 [==============================] - 14s 95ms/step - loss: 0.0648 - val_loss: 0.0034
# Epoch 18/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0045
# Epoch 00018: val_loss did not improve from 0.00334
# 144/144 [==============================] - 14s 96ms/step - loss: 0.0045 - val_loss: 0.0034
# Epoch 19/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0053
# Epoch 00019: val_loss improved from 0.00334 to 0.00329, saving model to ./models/trans_tom_BiLSTM.h5
# 144/144 [==============================] - 14s 95ms/step - loss: 0.0053 - val_loss: 0.0033
# Epoch 20/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0075
# Epoch 00020: val_loss did not improve from 0.00329
# 144/144 [==============================] - 14s 97ms/step - loss: 0.0075 - val_loss: 0.0033
# Epoch 21/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0059
# Epoch 00021: val_loss did not improve from 0.00329
# 144/144 [==============================] - 14s 96ms/step - loss: 0.0059 - val_loss: 0.0034
# Epoch 22/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0042
# Epoch 00022: val_loss did not improve from 0.00329
# 144/144 [==============================] - 14s 96ms/step - loss: 0.0042 - val_loss: 0.0034
# Epoch 23/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0036
# Epoch 00023: val_loss did not improve from 0.00329
# 144/144 [==============================] - 14s 98ms/step - loss: 0.0036 - val_loss: 0.0033
# Epoch 24/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0372
# Epoch 00024: val_loss did not improve from 0.00329
# 144/144 [==============================] - 14s 96ms/step - loss: 0.0374 - val_loss: 0.0039
# Epoch 25/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0856
# Epoch 00025: val_loss improved from 0.00329 to 0.00324, saving model to ./models/trans_tom_BiLSTM.h5
# 144/144 [==============================] - 14s 96ms/step - loss: 0.0850 - val_loss: 0.0032

# %%
raw_bilstm_model = tf.keras.models.Sequential([
    tf.keras.layers.LSTM(N_HIDDEN, input_shape=train_input.shape[-2:], return_sequences=True),
    tf.keras.layers.LayerNormalization(), # TEST
    tf.keras.layers.Dense(test_label.shape[-1])
])

# %%
raw_bilstm_model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
                   loss = tf.keras.losses.MeanSquaredError())

# %%
callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        filepath=RAW_BEST_PATHS[3],
        save_best_only=True,
        monitor='val_loss',
        verbose=1),
    tf.keras.callbacks.EarlyStopping(
  monitor='val_loss', min_delta=0.0001,  patience=20)
]

# %%
raw_bilstm_model.fit(
    train_dataset, epochs = 150,
    steps_per_epoch = 144,
    callbacks=callbacks,
    validation_data = test_dataset, validation_steps = 50)
# Out:
# Train for 144 steps, validate for 50 steps
# Epoch 1/150
# 138/144 [===========================>..] - ETA: 0s - loss: 0.0570
# Epoch 00001: val_loss improved from inf to 0.00607, saving model to ./models/raw_tom_BiLSTM.h5
# 144/144 [==============================] - 4s 25ms/step - loss: 0.0549 - val_loss: 0.0061
# Epoch 2/150
# 141/144 [============================>.] - ETA: 0s - loss: 0.0084
# Epoch 00002: val_loss did not improve from 0.00607
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0084 - val_loss: 0.0066
# Epoch 3/150
# 138/144 [===========================>..] - ETA: 0s - loss: 0.0092
# Epoch 00003: val_loss improved from 0.00607 to 0.00598, saving model to ./models/raw_tom_BiLSTM.h5
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0093 - val_loss: 0.0060
# Epoch 4/150
# 139/144 [===========================>..] - ETA: 0s - loss: 0.0109
# Epoch 00004: val_loss did not improve from 0.00598
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0109 - val_loss: 0.0071
# Epoch 5/150
# 139/144 [===========================>..] - ETA: 0s - loss: 0.0073
# Epoch 00005: val_loss improved from 0.00598 to 0.00496, saving model to ./models/raw_tom_BiLSTM.h5
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0073 - val_loss: 0.0050
# Epoch 6/150
# 139/144 [===========================>..] - ETA: 0s - loss: 0.0059
# Epoch 00006: val_loss did not improve from 0.00496
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0060 - val_loss: 0.0053
# Epoch 7/150
# 139/144 [===========================>..] - ETA: 0s - loss: 0.0110
# Epoch 00007: val_loss did not improve from 0.00496
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0112 - val_loss: 0.0079
# Epoch 8/150
# 138/144 [===========================>..] - ETA: 0s - loss: 0.1596
# Epoch 00008: val_loss did not improve from 0.00496
# 144/144 [==============================] - 2s 12ms/step - loss: 0.1602 - val_loss: 0.0590
# Epoch 9/150
# 138/144 [===========================>..] - ETA: 0s - loss: 0.0449
# Epoch 00009: val_loss did not improve from 0.00496
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0433 - val_loss: 0.0052
# Epoch 10/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0061
# Epoch 00010: val_loss improved from 0.00496 to 0.00473, saving model to ./models/raw_tom_BiLSTM.h5
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0061 - val_loss: 0.0047
# Epoch 11/150
# 139/144 [===========================>..] - ETA: 0s - loss: 0.0077
# Epoch 00011: val_loss improved from 0.00473 to 0.00466, saving model to ./models/raw_tom_BiLSTM.h5
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0078 - val_loss: 0.0047
# Epoch 12/150
# 139/144 [===========================>..] - ETA: 0s - loss: 0.0100
# Epoch 00012: val_loss improved from 0.00466 to 0.00453, saving model to ./models/raw_tom_BiLSTM.h5
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0100 - val_loss: 0.0045
# Epoch 13/150
# 139/144 [===========================>..] - ETA: 0s - loss: 0.0073
# Epoch 00013: val_loss did not improve from 0.00453
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0072 - val_loss: 0.0045
# Epoch 14/150
# 139/144 [===========================>..] - ETA: 0s - loss: 0.0059
# Epoch 00014: val_loss did not improve from 0.00453
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0059 - val_loss: 0.0049
# Epoch 15/150
# 138/144 [===========================>..] - ETA: 0s - loss: 0.0054
# Epoch 00015: val_loss did not improve from 0.00453
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0054 - val_loss: 0.0053
# Epoch 16/150
# 138/144 [===========================>..] - ETA: 0s - loss: 0.0872
# Epoch 00016: val_loss did not improve from 0.00453
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0895 - val_loss: 0.0064
# Epoch 17/150
# 138/144 [===========================>..] - ETA: 0s - loss: 0.0761
# Epoch 00017: val_loss did not improve from 0.00453
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0732 - val_loss: 0.0047
# Epoch 18/150
# 139/144 [===========================>..] - ETA: 0s - loss: 0.0061
# Epoch 00018: val_loss did not improve from 0.00453
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0060 - val_loss: 0.0046
# Epoch 19/150
# 139/144 [===========================>..] - ETA: 0s - loss: 0.0065
# Epoch 00019: val_loss did not improve from 0.00453
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0066 - val_loss: 0.0052
# Epoch 20/150
# 138/144 [===========================>..] - ETA: 0s - loss: 0.0098
# Epoch 00020: val_loss did not improve from 0.00453
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0098 - val_loss: 0.0049
# Epoch 21/150
# 138/144 [===========================>..] - ETA: 0s - loss: 0.0082
# Epoch 00021: val_loss improved from 0.00453 to 0.00437, saving model to ./models/raw_tom_BiLSTM.h5
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0082 - val_loss: 0.0044
# Epoch 22/150
# 139/144 [===========================>..] - ETA: 0s - loss: 0.0057
# Epoch 00022: val_loss did not improve from 0.00437
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0057 - val_loss: 0.0046
# Epoch 23/150
# 138/144 [===========================>..] - ETA: 0s - loss: 0.0050
# Epoch 00023: val_loss did not improve from 0.00437
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0050 - val_loss: 0.0051
# Epoch 24/150
# 138/144 [===========================>..] - ETA: 0s - loss: 0.0403
# Epoch 00024: val_loss did not improve from 0.00437
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0438 - val_loss: 0.0073
# Epoch 25/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.1046
# Epoch 00025: val_loss did not improve from 0.00437
# 144/144 [==============================] - 2s 12ms/step - loss: 0.1039 - val_loss: 0.0047
# Epoch 26/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0062
# Epoch 00026: val_loss did not improve from 0.00437
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0062 - val_loss: 0.0048
# Epoch 27/150
# 138/144 [===========================>..] - ETA: 0s - loss: 0.0066
# Epoch 00027: val_loss did not improve from 0.00437
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0067 - val_loss: 0.0048
# Epoch 28/150
# 139/144 [===========================>..] - ETA: 0s - loss: 0.0091
# Epoch 00028: val_loss did not improve from 0.00437
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0091 - val_loss: 0.0050
# Epoch 29/150
# 139/144 [===========================>..] - ETA: 0s - loss: 0.0087
# Epoch 00029: val_loss did not improve from 0.00437
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0087 - val_loss: 0.0048
# Epoch 30/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0058
# Epoch 00030: val_loss did not improve from 0.00437
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0058 - val_loss: 0.0049
# Epoch 31/150
# 141/144 [============================>.] - ETA: 0s - loss: 0.0050
# Epoch 00031: val_loss did not improve from 0.00437
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0050 - val_loss: 0.0051
# Epoch 32/150
# 138/144 [===========================>..] - ETA: 0s - loss: 0.0181
# Epoch 00032: val_loss did not improve from 0.00437
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0210 - val_loss: 0.0115
# Epoch 33/150
# 138/144 [===========================>..] - ETA: 0s - loss: 0.1328
# Epoch 00033: val_loss did not improve from 0.00437
# 144/144 [==============================] - 2s 12ms/step - loss: 0.1275 - val_loss: 0.0048
# Epoch 34/150
# 139/144 [===========================>..] - ETA: 0s - loss: 0.0059
# Epoch 00034: val_loss did not improve from 0.00437
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0059 - val_loss: 0.0047
# Epoch 35/150
# 139/144 [===========================>..] - ETA: 0s - loss: 0.0059
# Epoch 00035: val_loss did not improve from 0.00437
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0060 - val_loss: 0.0048
# Epoch 36/150
# 138/144 [===========================>..] - ETA: 0s - loss: 0.0085
# Epoch 00036: val_loss did not improve from 0.00437
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0086 - val_loss: 0.0045
# Epoch 37/150
# 138/144 [===========================>..] - ETA: 0s - loss: 0.0093
# Epoch 00037: val_loss did not improve from 0.00437
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0092 - val_loss: 0.0044
# Epoch 38/150
# 143/144 [============================>.] - ETA: 0s - loss: 0.0061
# Epoch 00038: val_loss did not improve from 0.00437
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0061 - val_loss: 0.0044
# Epoch 39/150
# 142/144 [============================>.] - ETA: 0s - loss: 0.0053
# Epoch 00039: val_loss did not improve from 0.00437
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0052 - val_loss: 0.0049
# Epoch 40/150
# 138/144 [===========================>..] - ETA: 0s - loss: 0.0072
# Epoch 00040: val_loss did not improve from 0.00437
# 144/144 [==============================] - 2s 12ms/step - loss: 0.0075 - val_loss: 0.0065
# Epoch 41/150
# 138/144 [===========================>..] - ETA: 0s - loss: 0.1082
# Epoch 00041: val_loss did not improve from 0.00437
# 144/144 [==============================] - 2s 12ms/step - loss: 0.1098 - val_loss: 0.0074

# %% [markdown]
# ### Model evaluation

# %%
bilstm_model = tf.keras.models.load_model(BEST_PATHS[3])
trans_bilstm_model = tf.keras.models.load_model(TRANS_BEST_PATHS[3])
raw_bilstm_model = tf.keras.models.load_model(RAW_BEST_PATHS[3])

# %%
bilstm_pred = bilstm_model.predict(test_dataset)
trans_bilstm_pred = trans_bilstm_model.predict(test_dataset)
raw_bilstm_pred = raw_bilstm_model.predict(test_dataset)

# %%
fig = plt.figure(figsize=((6/2.54)*4, (6/2.54)*4))

plt.scatter(tf.cast(tf.reshape(((MAXS-MINS)*test_label + MINS)[:, :, 0], (-1, 1)), tf.float32),
            tf.cast(tf.reshape(((MAXS-MINS)*bilstm_pred + MINS)[:, :, 0], (-1, 1)), tf.float32),
            c=cmap[3], s=2, alpha=0.3
           )
plt.scatter(tf.cast(tf.reshape(((MAXS-MINS)*test_label + MINS)[:, :, 0], (-1, 1)), tf.float32),
            tf.cast(tf.reshape(((MAXS-MINS)*raw_bilstm_pred + MINS)[:, :, 0], (-1, 1)), tf.float32),
            c=cmap[4], s=2, alpha=0.3
           )
plt.scatter(tf.cast(tf.reshape(((MAXS-MINS)*test_label + MINS)[:, :, 0], (-1, 1)), tf.float32),
            tf.cast(tf.reshape(((MAXS-MINS)*trans_bilstm_pred + MINS)[:, :, 0], (-1, 1)), tf.float32),
            c=cmap[0], s=2, alpha=0.3
           )
plt.axis([-10,50,-10,50])
# Out:
# [-10, 50, -10, 50]

# %%
x_t = np.arange(0, test_label.shape[1])
for _ in range (6):

        NUMBERS = np.arange(1, bilstm_pred.shape[0])
        np.random.shuffle(NUMBERS)
        NUMBERS = NUMBERS[:6]
        position = 331
        fig = plt.figure(figsize=((8.5/2.54)*4, (6/2.54)*4))
        
        i=0
        for NUMBER in NUMBERS:
            ax = plt.subplot(position)
            measured1 = plt.plot(x_t, test_label[NUMBER, :, i], c='k', alpha=1) #measured
            expect1 = plt.plot(x_t, bilstm_pred[NUMBER, :, i], c=cmap[3], alpha=0.8) #estimated
            expect1 = plt.plot(x_t, raw_bilstm_pred[NUMBER, :, i], c=cmap[4], alpha=0.8) #estimated
            expect1 = plt.plot(x_t, trans_bilstm_pred[NUMBER, :, i], c=cmap[0], alpha=0.8) #estimated
            ax.axis('off')

            position += 1
        plt.show()
        _ += 1
