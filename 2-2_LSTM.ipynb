# %%
import time
import os

import pandas as pd
import numpy as np
from sklearn.utils import resample
from sklearn.metrics import mean_squared_error

import tensorflow as tf
tf.__version__
# Out:
# '2.0.0'

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 2 Physical GPUs, 2 Logical GPUs

# %%
from tensorflow.keras.metrics import Metric
class RSquare(Metric):
    """Compute R^2 score.
     This is also called as coefficient of determination.
     It tells how close are data to the fitted regression line.
     - Highest score can be 1.0 and it indicates that the predictors
       perfectly accounts for variation in the target.
     - Score 0.0 indicates that the predictors do not
       account for variation in the target.
     - It can also be negative if the model is worse.
     Usage:
     ```python
     actuals = tf.constant([1, 4, 3], dtype=tf.float32)
     preds = tf.constant([2, 4, 4], dtype=tf.float32)
     result = tf.keras.metrics.RSquare()
     result.update_state(actuals, preds)
     print('R^2 score is: ', r1.result().numpy()) # 0.57142866
    ```
    """

    def __init__(self, name='r_square', dtype=tf.float32):
        super(RSquare, self).__init__(name=name, dtype=dtype)
        self.squared_sum = self.add_weight("squared_sum", initializer="zeros")
        self.sum = self.add_weight("sum", initializer="zeros")
        self.res = self.add_weight("residual", initializer="zeros")
        self.count = self.add_weight("count", initializer="zeros")

    def update_state(self, y_true, y_pred):
        y_true = tf.convert_to_tensor(y_true, tf.float32)
        y_pred = tf.convert_to_tensor(y_pred, tf.float32)
        self.squared_sum.assign_add(tf.reduce_sum(y_true**2))
        self.sum.assign_add(tf.reduce_sum(y_true))
        self.res.assign_add(
            tf.reduce_sum(tf.square(tf.subtract(y_true, y_pred))))
        self.count.assign_add(tf.cast(tf.shape(y_true)[0], tf.float32))

    def result(self):
        mean = self.sum / self.count
        total = self.squared_sum - 2 * self.sum * mean + self.count * mean**2
        return 1 - (self.res / total)

    def reset_states(self):
        # The state of the metric will be reset at the start of each epoch.
        self.squared_sum.assign(0.0)
        self.sum.assign(0.0)
        self.res.assign(0.0)
        self.count.assign(0.0)

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.rcParams['figure.figsize'] = ((8/2.54), (6/2.54))
plt.rcParams["font.family"] = "Arial"
plt.rcParams["mathtext.default"] = "rm"
plt.rcParams.update({'font.size': 11})
MARKER_SIZE = 15
cmap_m = ["#f4a6ad", "#f6957e", "#fccfa2", "#8de7be", "#86d6f2", "#24a9e4", "#b586e0", "#d7f293"]
cmap = ["#e94d5b", "#ef4d28", "#f9a54f", "#25b575", "#1bb1e7", "#1477a2", "#a662e5", "#c2f442"]

plt.rcParams['axes.spines.top'] = False
# plt.rcParams['axes.edgecolor'] = 
plt.rcParams['axes.linewidth'] = 1
plt.rcParams['lines.linewidth'] = 1.5
plt.rcParams['xtick.major.width'] = 1
plt.rcParams['xtick.minor.width'] = 1
plt.rcParams['ytick.major.width'] = 1
plt.rcParams['ytick.minor.width'] = 1

# %% [markdown]
# # Model training

# %% [markdown]
# ## Hyperparameters

# %%
EX_PRED = 0
TRAINING_EPOCHS = 50
LIMIT = 3002
SHIELD = 5
BEST_PATH = "./models/best_LSTM.h5"

TIME_STEPS = 180
LEARNING_RATE = 0.001
EPSILON = 1e-04
N_HIDDEN = 256
BATCH_SIZE = 32
VAL_STEP = 500

# %% [markdown]
# ## data loading

# %%
l = np.load('./env_set/dataset.npz')
train_input = l['train_input']
train_label = l['train_label']
test_input = l['test_input']
test_label = l['test_label']
MAXS = l['MAXS']
MINS = l['MINS']

TIME_STEPS = l['TIME_STEPS']
OUTPUT_SIZE = l['OUTPUT_SIZE']
NUM_FEATURES = train_input.shape[-1]

# %%
print(train_input.shape)
print(train_label.shape)
# Out:
# (41025, 24, 5)
# (41025, 24, 5)

# %%
print(test_input.shape)
print(test_label.shape)
# Out:
# (16119, 24, 5)
# (16119, 24, 5)

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((train_input, train_label))
train_dataset = train_dataset.cache().shuffle(BATCH_SIZE*50).batch(BATCH_SIZE).repeat()
test_dataset = tf.data.Dataset.from_tensor_slices((test_input, test_label))
test_dataset = test_dataset.batch(BATCH_SIZE)

# %%
with tf.device('/device:GPU:1'):
    lstm_model = tf.keras.models.Sequential([
        tf.keras.layers.LSTM(N_HIDDEN, input_shape=train_input.shape[-2:], return_sequences=True),
        tf.keras.layers.LayerNormalization(), # TEST
        tf.keras.layers.Dense(test_label.shape[-1])
    ])

# %%
lstm_model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE, epsilon=EPSILON),
                   loss = tf.keras.losses.MeanSquaredError())
lstm_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 24, 256)           268288
# _________________________________________________________________
# layer_normalization (LayerNo (None, 24, 256)           512
# _________________________________________________________________
# dense (Dense)                (None, 24, 5)             1285
# =================================================================
# Total params: 270,085
# Trainable params: 270,085
# Non-trainable params: 0
# _________________________________________________________________

# %%
callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        filepath=BEST_PATH,
        # Path where to save the model
        # The two parameters below mean that we will overwrite
        # the current checkpoint if and only if
        # the `val_loss` score has improved.
        save_best_only=True,
        monitor='val_loss',
        verbose=1),
    tf.keras.callbacks.EarlyStopping(
  monitor='val_loss', min_delta=0.0001,  patience=20)
]

# %%
lstm_model.fit(
    train_dataset, epochs = TRAINING_EPOCHS,
    steps_per_epoch = 144,
    callbacks=callbacks,
    validation_data = test_dataset, validation_steps = 50)
# Out:
# Train for 144 steps, validate for 50 steps
# Epoch 1/50
# 139/144 [===========================>..] - ETA: 0s - loss: 0.0644
# Epoch 00001: val_loss improved from inf to 0.01287, saving model to ./models/best_LSTM.h5
# 144/144 [==============================] - 6s 44ms/step - loss: 0.0625 - val_loss: 0.0129
# Epoch 2/50
# 141/144 [============================>.] - ETA: 0s - loss: 0.0100
# Epoch 00002: val_loss improved from 0.01287 to 0.01093, saving model to ./models/best_LSTM.h5
# 144/144 [==============================] - 2s 15ms/step - loss: 0.0099 - val_loss: 0.0109
# Epoch 3/50
# 139/144 [===========================>..] - ETA: 0s - loss: 0.0090
# Epoch 00003: val_loss did not improve from 0.01093
# 144/144 [==============================] - 2s 15ms/step - loss: 0.0091 - val_loss: 0.0144
# Epoch 4/50
# 139/144 [===========================>..] - ETA: 0s - loss: 0.0062
# Epoch 00004: val_loss improved from 0.01093 to 0.01033, saving model to ./models/best_LSTM.h5
# 144/144 [==============================] - 2s 15ms/step - loss: 0.0062 - val_loss: 0.0103
# Epoch 5/50
# 140/144 [============================>.] - ETA: 0s - loss: 0.0072
# Epoch 00005: val_loss did not improve from 0.01033
# 144/144 [==============================] - 2s 14ms/step - loss: 0.0072 - val_loss: 0.0109
# Epoch 6/50
# 141/144 [============================>.] - ETA: 0s - loss: 0.0077
# Epoch 00006: val_loss did not improve from 0.01033
# 144/144 [==============================] - 2s 15ms/step - loss: 0.0077 - val_loss: 0.0142
# Epoch 7/50
# 141/144 [============================>.] - ETA: 0s - loss: 0.0077
# Epoch 00007: val_loss did not improve from 0.01033
# 144/144 [==============================] - 2s 15ms/step - loss: 0.0077 - val_loss: 0.0104
# Epoch 8/50
# 139/144 [===========================>..] - ETA: 0s - loss: 0.0089
# Epoch 00008: val_loss did not improve from 0.01033
# 144/144 [==============================] - 2s 14ms/step - loss: 0.0090 - val_loss: 0.0115
# Epoch 9/50
# 141/144 [============================>.] - ETA: 0s - loss: 0.0104
# Epoch 00009: val_loss did not improve from 0.01033
# 144/144 [==============================] - 2s 15ms/step - loss: 0.0103 - val_loss: 0.0129
# Epoch 10/50
# 141/144 [============================>.] - ETA: 0s - loss: 0.0072
# Epoch 00010: val_loss did not improve from 0.01033
# 144/144 [==============================] - 2s 14ms/step - loss: 0.0073 - val_loss: 0.0107
# Epoch 11/50
# 141/144 [============================>.] - ETA: 0s - loss: 0.0078
# Epoch 00011: val_loss improved from 0.01033 to 0.01027, saving model to ./models/best_LSTM.h5
# 144/144 [==============================] - 2s 15ms/step - loss: 0.0078 - val_loss: 0.0103
# Epoch 12/50
# 141/144 [============================>.] - ETA: 0s - loss: 0.0083
# Epoch 00012: val_loss improved from 0.01027 to 0.00957, saving model to ./models/best_LSTM.h5
# 144/144 [==============================] - 2s 14ms/step - loss: 0.0083 - val_loss: 0.0096
# Epoch 13/50
# 143/144 [============================>.] - ETA: 0s - loss: 0.0056
# Epoch 00013: val_loss did not improve from 0.00957
# 144/144 [==============================] - 2s 14ms/step - loss: 0.0056 - val_loss: 0.0103
# Epoch 14/50
# 140/144 [============================>.] - ETA: 0s - loss: 0.0070
# Epoch 00014: val_loss did not improve from 0.00957
# 144/144 [==============================] - 2s 14ms/step - loss: 0.0070 - val_loss: 0.0114
# Epoch 15/50
# 143/144 [============================>.] - ETA: 0s - loss: 0.0073
# Epoch 00015: val_loss did not improve from 0.00957
# 144/144 [==============================] - 2s 15ms/step - loss: 0.0073 - val_loss: 0.0106
# Epoch 16/50
# 142/144 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 00016: val_loss did not improve from 0.00957
# 144/144 [==============================] - 2s 16ms/step - loss: 0.0071 - val_loss: 0.0172
# Epoch 17/50
# 143/144 [============================>.] - ETA: 0s - loss: 0.0092
# Epoch 00017: val_loss did not improve from 0.00957
# 144/144 [==============================] - 2s 16ms/step - loss: 0.0093 - val_loss: 0.0146
# Epoch 18/50
# 141/144 [============================>.] - ETA: 0s - loss: 0.0099
# Epoch 00018: val_loss did not improve from 0.00957
# 144/144 [==============================] - 2s 16ms/step - loss: 0.0099 - val_loss: 0.0103
# Epoch 19/50
# 140/144 [============================>.] - ETA: 0s - loss: 0.0068
# Epoch 00019: val_loss improved from 0.00957 to 0.00949, saving model to ./models/best_LSTM.h5
# 144/144 [==============================] - 2s 16ms/step - loss: 0.0068 - val_loss: 0.0095
# Epoch 20/50
# 143/144 [============================>.] - ETA: 0s - loss: 0.0076
# Epoch 00020: val_loss did not improve from 0.00949
# 144/144 [==============================] - 2s 16ms/step - loss: 0.0076 - val_loss: 0.0099
# Epoch 21/50
# 142/144 [============================>.] - ETA: 0s - loss: 0.0079
# Epoch 00021: val_loss did not improve from 0.00949
# 144/144 [==============================] - 2s 16ms/step - loss: 0.0079 - val_loss: 0.0106
# Epoch 22/50
# 141/144 [============================>.] - ETA: 0s - loss: 0.0056
# Epoch 00022: val_loss did not improve from 0.00949
# 144/144 [==============================] - 2s 16ms/step - loss: 0.0056 - val_loss: 0.0099
# Epoch 23/50
# 143/144 [============================>.] - ETA: 0s - loss: 0.0067
# Epoch 00023: val_loss did not improve from 0.00949
# 144/144 [==============================] - 2s 15ms/step - loss: 0.0067 - val_loss: 0.0101
# Epoch 24/50
# 142/144 [============================>.] - ETA: 0s - loss: 0.0072
# Epoch 00024: val_loss did not improve from 0.00949
# 144/144 [==============================] - 2s 16ms/step - loss: 0.0072 - val_loss: 0.0098
# Epoch 25/50
# 143/144 [============================>.] - ETA: 0s - loss: 0.0067
# Epoch 00025: val_loss did not improve from 0.00949
# 144/144 [==============================] - 2s 16ms/step - loss: 0.0067 - val_loss: 0.0114
# Epoch 26/50
# 141/144 [============================>.] - ETA: 0s - loss: 0.0086
# Epoch 00026: val_loss did not improve from 0.00949
# 144/144 [==============================] - 2s 15ms/step - loss: 0.0087 - val_loss: 0.0096
# Epoch 27/50
# 141/144 [============================>.] - ETA: 0s - loss: 0.0093
# Epoch 00027: val_loss improved from 0.00949 to 0.00914, saving model to ./models/best_LSTM.h5
# 144/144 [==============================] - 2s 16ms/step - loss: 0.0093 - val_loss: 0.0091
# Epoch 28/50
# 141/144 [============================>.] - ETA: 0s - loss: 0.0067
# Epoch 00028: val_loss did not improve from 0.00914
# 144/144 [==============================] - 2s 16ms/step - loss: 0.0067 - val_loss: 0.0104
# Epoch 29/50
# 141/144 [============================>.] - ETA: 0s - loss: 0.0073
# Epoch 00029: val_loss did not improve from 0.00914
# 144/144 [==============================] - 2s 16ms/step - loss: 0.0073 - val_loss: 0.0097
# Epoch 30/50
# 142/144 [============================>.] - ETA: 0s - loss: 0.0077
# Epoch 00030: val_loss improved from 0.00914 to 0.00899, saving model to ./models/best_LSTM.h5
# 144/144 [==============================] - 2s 16ms/step - loss: 0.0076 - val_loss: 0.0090
# Epoch 31/50
# 141/144 [============================>.] - ETA: 0s - loss: 0.0055
# Epoch 00031: val_loss did not improve from 0.00899
# 144/144 [==============================] - 2s 15ms/step - loss: 0.0056 - val_loss: 0.0104
# Epoch 32/50
# 142/144 [============================>.] - ETA: 0s - loss: 0.0062
# Epoch 00032: val_loss did not improve from 0.00899
# 144/144 [==============================] - 2s 16ms/step - loss: 0.0063 - val_loss: 0.0098
# Epoch 33/50
# 142/144 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 00033: val_loss did not improve from 0.00899
# 144/144 [==============================] - 2s 16ms/step - loss: 0.0071 - val_loss: 0.0098
# Epoch 34/50
# 142/144 [============================>.] - ETA: 0s - loss: 0.0063
# Epoch 00034: val_loss did not improve from 0.00899
# 144/144 [==============================] - 2s 16ms/step - loss: 0.0063 - val_loss: 0.0110
# Epoch 35/50
# 142/144 [============================>.] - ETA: 0s - loss: 0.0093
# Epoch 00035: val_loss did not improve from 0.00899
# 144/144 [==============================] - 2s 15ms/step - loss: 0.0093 - val_loss: 0.0105
# Epoch 36/50
# 140/144 [============================>.] - ETA: 0s - loss: 0.0089
# Epoch 00036: val_loss did not improve from 0.00899
# 144/144 [==============================] - 2s 16ms/step - loss: 0.0088 - val_loss: 0.0091
# Epoch 37/50
# 142/144 [============================>.] - ETA: 0s - loss: 0.0068
# Epoch 00037: val_loss did not improve from 0.00899
# 144/144 [==============================] - 2s 16ms/step - loss: 0.0068 - val_loss: 0.0094
# Epoch 38/50
# 143/144 [============================>.] - ETA: 0s - loss: 0.0069
# Epoch 00038: val_loss did not improve from 0.00899
# 144/144 [==============================] - 2s 16ms/step - loss: 0.0070 - val_loss: 0.0094
# Epoch 39/50
# 141/144 [============================>.] - ETA: 0s - loss: 0.0070
# Epoch 00039: val_loss improved from 0.00899 to 0.00885, saving model to ./models/best_LSTM.h5
# 144/144 [==============================] - 2s 16ms/step - loss: 0.0070 - val_loss: 0.0089
# Epoch 40/50
# 142/144 [============================>.] - ETA: 0s - loss: 0.0057
# Epoch 00040: val_loss did not improve from 0.00885
# 144/144 [==============================] - 2s 16ms/step - loss: 0.0057 - val_loss: 0.0118
# Epoch 41/50
# 143/144 [============================>.] - ETA: 0s - loss: 0.0061
# Epoch 00041: val_loss did not improve from 0.00885
# 144/144 [==============================] - 2s 16ms/step - loss: 0.0061 - val_loss: 0.0096
# Epoch 42/50
# 141/144 [============================>.] - ETA: 0s - loss: 0.0072
# Epoch 00042: val_loss did not improve from 0.00885
# 144/144 [==============================] - 2s 16ms/step - loss: 0.0072 - val_loss: 0.0104
# Epoch 43/50
# 141/144 [============================>.] - ETA: 0s - loss: 0.0062
# Epoch 00043: val_loss did not improve from 0.00885
# 144/144 [==============================] - 2s 16ms/step - loss: 0.0062 - val_loss: 0.0117
# Epoch 44/50
# 141/144 [============================>.] - ETA: 0s - loss: 0.0090
# Epoch 00044: val_loss did not improve from 0.00885
# 144/144 [==============================] - 2s 15ms/step - loss: 0.0090 - val_loss: 0.0093
# Epoch 45/50
# 142/144 [============================>.] - ETA: 0s - loss: 0.0083
# Epoch 00045: val_loss did not improve from 0.00885
# 144/144 [==============================] - 2s 16ms/step - loss: 0.0083 - val_loss: 0.0090
# Epoch 46/50
# 143/144 [============================>.] - ETA: 0s - loss: 0.0066
# Epoch 00046: val_loss did not improve from 0.00885
# 144/144 [==============================] - 2s 16ms/step - loss: 0.0066 - val_loss: 0.0094
# Epoch 47/50
# 141/144 [============================>.] - ETA: 0s - loss: 0.0068
# Epoch 00047: val_loss did not improve from 0.00885
# 144/144 [==============================] - 2s 16ms/step - loss: 0.0068 - val_loss: 0.0095
# Epoch 48/50
# 142/144 [============================>.] - ETA: 0s - loss: 0.0068
# Epoch 00048: val_loss did not improve from 0.00885
# 144/144 [==============================] - 2s 16ms/step - loss: 0.0067 - val_loss: 0.0110
# Epoch 49/50
# 143/144 [============================>.] - ETA: 0s - loss: 0.0058
# Epoch 00049: val_loss did not improve from 0.00885
# 144/144 [==============================] - 2s 15ms/step - loss: 0.0058 - val_loss: 0.0095
# Epoch 50/50
# 141/144 [============================>.] - ETA: 0s - loss: 0.0061
# Epoch 00050: val_loss did not improve from 0.00885
# 144/144 [==============================] - 2s 15ms/step - loss: 0.0061 - val_loss: 0.0095

# %%
test_loss = lstm_model.evaluate(test_dataset, steps=50)

print('Test Loss: {}'.format(test_loss))
#print('Test Accuracy: {}'.format(test_acc))
# Out:
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0095
# Test Loss: 0.009466783506795765

# %%
pred_result = lstm_model.predict(test_dataset, steps=20)

# %% [markdown]
# # Model evaluation

# %%
trained_model = tf.keras.models.load_model(BEST_PATH)
trained_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 24, 256)           268288
# _________________________________________________________________
# layer_normalization (LayerNo (None, 24, 256)           512
# _________________________________________________________________
# dense (Dense)                (None, 24, 5)             1285
# =================================================================
# Total params: 270,085
# Trainable params: 270,085
# Non-trainable params: 0
# _________________________________________________________________

# %%
np.set_printoptions(precision=6, suppress=True)

# %%
pred_result = trained_model.predict(test_dataset)

# %%
print(pred_result.shape)
print(test_label.shape)
# Out:
# (16119, 24, 5)
# (16119, 24, 5)

# %%
for _ in range(test_label.shape[-1]):
    print(np.sqrt(mean_squared_error(test_label[:, :, _].reshape(-1), pred_result[:, :, _].reshape(-1))))
# Out:
# 0.0683367524225678
# 0.05866105546077306
# 0.09482734843797436
# 0.05309619002081231
# 0.14849959415068845

# %%
r2 = RSquare()
for _ in range(test_label.shape[-1]):
    r2.reset_states()
    print(r2(tf.cast(test_label[:, :, _].reshape(-1), tf.float32), tf.cast(pred_result[:, :, _].reshape(-1), tf.float32)))
# Out:
# tf.Tensor(0.7577373, shape=(), dtype=float32)
# tf.Tensor(0.8762705, shape=(), dtype=float32)
# tf.Tensor(0.72949284, shape=(), dtype=float32)
# tf.Tensor(0.46127534, shape=(), dtype=float32)
# tf.Tensor(0.6490009, shape=(), dtype=float32)

# %%
fig = plt.figure(figsize=((8/2.54)*4, (6/2.54)*4))
x = np.arange(0,2)
plt.plot(x, x, 'k')
plt.scatter(tf.cast(tf.reshape(((MAXS-MINS)*test_label + MINS)[:, :, 0], (-1, 1)), tf.float32),
            tf.cast(tf.reshape(((MAXS-MINS)*pred_result + MINS)[:, :, 0], (-1, 1)), tf.float32),
            c=cmap[0], s=2
           )
plt.axis([10,40,10,40])
#plt.plot(x, tf.nn.softmax(logit[0][0, 5, :]).numpy(), c=cmap[0], alpha=0.2)
#plt.plot(x, tf.nn.softmax(logit[0][0, -1, :]).numpy(), c=cmap[3], alpha=0.2)
# Out:
# [10, 40, 10, 40]

# %%
x_t = np.arange(0, test_label.shape[1])
for _ in range (6):

        NUMBERS = np.arange(1, pred_result.shape[0])
        np.random.shuffle(NUMBERS)
        NUMBERS = NUMBERS[:6]
        position = 331
        fig = plt.figure(figsize=((8.5/2.54)*8, (6/2.54)*8))
        
        i=3
        for NUMBER in NUMBERS:
            ax = plt.subplot(position)
            measured1 = plt.plot(x_t, test_label[NUMBER, :, i], c=cmap[0], alpha=0.8) #measured
            expect1 = plt.plot(x_t, pred_result[NUMBER, :, i], c=cmap[5], alpha=0.4) #estimated
            ax.axis('off')

            position += 1
        plt.show()
        _ += 1
